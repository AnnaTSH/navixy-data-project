# %%
import requests
import pandas as pd
import json

# %%
url = "https://api.eu.navixy.com/v2/tracker/list"

headers = {
    # Added when you pass json=
    # 'Content-Type': 'application/json',
}

json_data = {
    'hash': 'feed000000000000000000000000cafe',
}
response = requests.post(url, headers=headers, json=json_data)
tracker_list = response.json()
tracker = pd.json_normalize(tracker_list['list'])

# %%
tracker.head(2)
# Out:
#        id          label  group_id tag_bindings  clone  \
# 0  877766    Steve (MAN)    105448           []  False
# 1  877767  John (Scania)    105448           []  False
#
#    source.status_listing_id  source.id source.device_id  source.blocked  \
# 0                       NaN     545138  979914665171717           False
# 1                       NaN     545139  693299870436055           False
#
#   source.creation_date  source.tariff_id source.model source.tariff_end_date  \
# 0           2021-08-09              1352   atoldrive5             2024-09-01
# 1           2021-08-09              1352   atoldrive5             2024-09-01
#
#   source.phone
# 0         None
# 1         None

# %%
tracker.to_csv('data/tracker.csv', index=False)

# %%
url = "https://api.eu.navixy.com/v2/employee/list"

json_data = {
    'hash': 'feed000000000000000000000000cafe',
}
response = requests.post(url, headers=headers, json=json_data)
employee_list = response.json()
employee = pd.json_normalize(employee_list['list'])
employee.to_csv('data/employee.csv', index=False)

# %%
url = "https://api.eu.navixy.com/v2/vehicle/list"

json_data = {
    'hash': 'feed000000000000000000000000cafe',
}
response = requests.post(url, headers=headers, json=json_data)
vehicle_list = response.json()
vehicle = pd.json_normalize(vehicle_list['list'])
vehicle.to_csv('data/vehicle.csv', index=False)

# %%
url = "https://api.eu.navixy.com/v2/tracker/get_states"

json_data = {
    'hash': 'feed000000000000000000000000cafe',
    'trackers': tracker.id.to_list(),
}
response = requests.post(url, headers=headers, json=json_data)
trackers_states = response.json()

# %%
df = pd.DataFrame.from_dict(trackers_states['states'], orient='index')
gps = pd.json_normalize(df['gps']).add_prefix('gps.')
gsm = pd.json_normalize(df['gsm']).add_prefix('gsm.')
df = pd.concat([df.reset_index().rename(columns={'index': 'id'}), gps, gsm], axis=1).drop(columns={"gps", "gsm"})

# %%
with pd.option_context("display.max_columns", 100, 'display.max_colwidth', 100):
    display(df.head(2))
# Out:
#         id  source_id connection_status movement_status          last_update  \
# 0  3036047   10230656           offline          parked  2024-07-23 04:11:54
# 1  3036045   10230654           offline          parked  2024-07-23 04:12:52
#
#    battery_level battery_update                                      inputs  \
# 0            NaN           None                                     [False]
# 1            NaN           None  [False, False, False, False, False, False]
#
#          inputs_update                outputs       outputs_update  \
# 0  2024-07-23 04:11:54                     []  2024-07-23 04:11:54
# 1  2024-07-23 04:12:52  [False, False, False]  2024-07-23 04:12:52
#
#    actual_track_update  \
# 0  2024-07-22 23:02:12
# 1  2024-07-22 21:41:39
#
#                                                          additional  \
# 0                                                               NaN
# 1  {'event_code': {'value': '0', 'updated': '2024-07-23 04:09:50'}}
#
#            gps.updated  gps.signal_level  gps.heading  gps.speed  gps.alt  \
# 0  2024-07-23 04:09:12               100           45          0        0
# 1  2024-07-23 04:09:50               100           45          0        0
#
#    gps.location.lat  gps.location.lng gsm.updated  gsm.signal_level  \
# 0         38.133215        -85.768903        None                 0
# 1         30.328325        -97.720808        None                 0
#
#   gsm.network_name gsm.roaming
# 0                         None
# 1                        False

# %%
df.movement_status.unique()
# Out:
# array(['parked', 'moving', 'stopped'], dtype=object)

# %%
df.to_csv('data/trackers_states.csv', index=False)

# %%
url = "https://api.eu.navixy.com/v2/tracker/get_fuel"

fuel_states = []

for tracker_id in tracker.id.to_list(): 
    json_data = {
        'hash': 'feed000000000000000000000000cafe',
        'tracker_id': tracker_id,
    }
    response = requests.post(url, headers=headers, json=json_data)
    fuel = response.json()
    
    # shouldn't be used, because in some cases "inputs" is an empty list
    # that corrupts other values: 'update_time', 'success'
    # df = pd.json_normalize(fuel, 'inputs', ['update_time', 'success']) 

    df = pd.json_normalize(fuel)
    df = df.explode('inputs')
    if pd.isna(df.loc[0, 'inputs']) == False:
        df = pd.concat([df, df['inputs'].apply(pd.Series)], axis=1)
    df['tracker_id'] = tracker_id
    fuel_states.append(df)

df = pd.concat(fuel_states, axis=0, ignore_index=True).drop(columns=['inputs', 'user_time'])
df.to_csv('data/fuel_states.csv', index=False)
# Out:
# /tmp/ipykernel_924/659681165.py:24: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(fuel_states, axis=0, ignore_index=True).drop(columns=['inputs', 'user_time'])

# %%
url = "https://api.eu.navixy.com/v2/tracker/get_diagnostics"

diagnostics = []

for tracker_id in tracker.id.to_list(): 
    json_data = {
        'hash': 'feed000000000000000000000000cafe',
        'tracker_id': tracker_id,
    }
    response = requests.post(url, headers=headers, json=json_data)
    diag = response.json()

    df = pd.json_normalize(diag)
    df = df.explode('inputs')
    if pd.isna(df.loc[0, 'inputs']) == False:
        df = pd.concat([df, df['inputs'].apply(pd.Series)], axis=1)
    df['tracker_id'] = tracker_id
    diagnostics.append(df)

df = pd.concat(diagnostics, axis=0, ignore_index=True).drop(columns=['inputs', 'user_time'])
df.to_csv('data/diagnostics.csv', index=False)

# %%
df
# Out:
#             update_time  success  tracker_id                    label units  \
# 0                  None     True      877766                      NaN   NaN
# 1                  None     True      877767                      NaN   NaN
# 2                  None     True      877768                      NaN   NaN
# 3                  None     True     3036043                      NaN   NaN
# 4                  None     True     3036045                      NaN   NaN
# 5                  None     True     3036047                      NaN   NaN
# 6                  None     True     3036049                      NaN   NaN
# 7   2024-07-23 04:07:21     True     3036056                OBD: Fuel
# 8   2024-07-23 00:39:56     True     3036057       CAN: Fuel (litres)     L
# 9                  None     True     3036059                      NaN   NaN
# 10                 None     True     3036060                      NaN   NaN
# 11                 None     True     1228833                      NaN   NaN
# 12  2024-07-23 04:09:17     True     3036068  OBD: Real Fuel (litres)
# 13  2024-07-23 03:54:17     True     3036069       CAN: Fuel (litres)
# 14                 None     True     3036070                      NaN   NaN
# 15                 None     True     3036071                      NaN   NaN
#
#                       name  type  value units_type converted_units_type  \
# 0                      NaN   NaN    NaN        NaN                  NaN
# 1                      NaN   NaN    NaN        NaN                  NaN
# 2                      NaN   NaN    NaN        NaN                  NaN
# 3                      NaN   NaN    NaN        NaN                  NaN
# 4                      NaN   NaN    NaN        NaN                  NaN
# 5                      NaN   NaN    NaN        NaN                  NaN
# 6                      NaN   NaN    NaN        NaN                  NaN
# 7                 obd_fuel  fuel   48.0    percent                 None
# 8          can_fuel_litres  fuel  695.0      litre                 None
# 9                      NaN   NaN    NaN        NaN                  NaN
# 10                     NaN   NaN    NaN        NaN                  NaN
# 11                     NaN   NaN    NaN        NaN                  NaN
# 12  obd_custom_fuel_litres  fuel   20.4      litre                 None
# 13         can_fuel_litres  fuel  927.0      litre                 None
# 14                     NaN   NaN    NaN        NaN                  NaN
# 15                     NaN   NaN    NaN        NaN                  NaN
#
#    converted_value
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7             None
# 8             None
# 9              NaN
# 10             NaN
# 11             NaN
# 12            None
# 13            None
# 14             NaN
# 15             NaN

# %%
url = "https://api.eu.navixy.com/v2/tracker/get_inputs"

inputs = []

for tracker_id in tracker.id.to_list(): 
    json_data = {
        'hash': 'feed000000000000000000000000cafe',
        'tracker_id': tracker_id,
    }
    response = requests.post(url, headers=headers, json=json_data)
    inp = response.json()

    df = pd.json_normalize(inp)
    df = df.explode('states')
    if pd.isna(df.loc[0, 'states']) == False:
        df = pd.concat([df, df['states'].apply(pd.Series)], axis=1)
    df['tracker_id'] = tracker_id
    inputs.append(df)

df = pd.concat(inputs, axis=0, ignore_index=True).drop(columns=['states', 'user_time'])
df.to_csv('data/inputs.csv', index=False)

# %%
df
# Out:
#             update_time                                      inputs  success  \
# 0   2024-07-23 04:10:01                       [False, False, False]     True
# 1   2024-07-23 04:09:59                       [False, False, False]     True
# 2   2024-07-23 04:10:01                       [False, False, False]     True
# 3   2024-07-23 04:11:54                       [False, False, False]     True
# 4   2024-07-23 04:12:52  [False, False, False, False, False, False]     True
# 5   2024-07-23 04:11:54                                     [False]     True
# 6   2024-07-23 04:12:52                                          []     True
# 7   2024-07-23 04:09:26                              [False, False]     True
# 8   2024-07-23 04:09:47         [False, False, False, False, False]     True
# 9   2024-07-23 04:11:54                       [False, False, False]     True
# 10  2024-07-23 04:12:52                                          []     True
# 11  2024-08-01 15:38:45                [False, False, False, False]     True
# 12  2024-07-23 04:09:17                                     [False]     True
# 13  2024-07-23 04:09:22         [False, False, False, False, False]     True
# 14  2024-07-23 04:11:54                [False, False, False, False]     True
# 15  2024-07-23 04:12:52                                          []     True
#
#     tracker_id      type        name status  input_number
# 0       877766       NaN         NaN    NaN           NaN
# 1       877767       NaN         NaN    NaN           NaN
# 2       877768       NaN         NaN    NaN           NaN
# 3      3036043  ignition    Ignition  False           1.0
# 4      3036045  ignition    Ignition  False           1.0
# 5      3036047  ignition    Ignition  False           1.0
# 6      3036049       NaN         NaN    NaN           NaN
# 7      3036056  ignition    Ignition  False           2.0
# 8      3036057  ignition    Ignition  False           1.0
# 9      3036059  ignition    Ignition  False           2.0
# 10     3036060       NaN         NaN    NaN           NaN
# 11     1228833  ignition  Zündung AN  False           4.0
# 12     3036068  ignition    Ignition  False           1.0
# 13     3036069  ignition    Ignition  False           5.0
# 14     3036070  ignition    Ignition  False           2.0
# 15     3036071       NaN         NaN    NaN           NaN

# %%
url = "https://api.eu.navixy.com/v2/track/get_last_gps_point"

gps_list = []

for tracker_id in tracker.id.to_list(): 
    json_data = {
        'hash': 'feed000000000000000000000000cafe',
        'tracker_id': tracker_id,
    }
    response = requests.post(url, headers=headers, json=json_data)
    df = pd.json_normalize(response.json())
    df['tracker_id'] = tracker_id
    gps_list.append(df)

df = pd.concat(gps_list, axis=0, ignore_index=True)
df.to_csv('data/last_gps_point.csv', index=False)

# %%
url = "https://api.eu.navixy.com/v2/tracker/get_readings"

readings = []

for tracker_id in tracker.id.to_list(): 
    json_data = {
        'hash': 'feed000000000000000000000000cafe',
        'tracker_id': tracker_id,
    }
    response = requests.post(url, headers=headers, json=json_data)
    read = response.json()

    df = pd.json_normalize(read)
    df = df.explode('inputs').reset_index(drop=True)
    if pd.isna(df.loc[0, 'inputs']) == False:
        df = pd.concat([df, df['inputs'].apply(pd.Series)], axis=1)
    df['tracker_id'] = tracker_id
    readings.append(df)

df = pd.concat(readings, axis=0, ignore_index=True).drop(columns=['inputs', 'user_time'])
df.to_csv('data/readings.csv', index=False)

# %%
url = "https://api.eu.navixy.com/v2/tracker/stats/mileage/read"
 
json_data = {
    'hash': 'feed000000000000000000000000cafe',
    'trackers': tracker.id.to_list(),
    "from": "2024-06-26 00:00:00", 
    "to": "2024-07-26 00:00:00",
}
response = requests.post(url, headers=headers, json=json_data)
mileage = response.json()

# %%
mileage
# Out:
# {'result': {'3036047': {'2024-06-26': {'mileage': 252.43},
#    '2024-06-27': {'mileage': 252.63},
#    '2024-06-28': {'mileage': 246.38},
#    '2024-06-29': {'mileage': 257.19},
#    '2024-06-30': {'mileage': 246.0},
#    '2024-07-01': {'mileage': 256.98},
#    '2024-07-02': {'mileage': 269.11},
#    '2024-07-03': {'mileage': 260.5},
#    '2024-07-04': {'mileage': 260.71},
#    '2024-07-05': {'mileage': 260.72},
#    '2024-07-06': {'mileage': 264.85},
#    '2024-07-07': {'mileage': 269.94},
#    '2024-07-08': {'mileage': 265.6},
#    '2024-07-09': {'mileage': 0.0},
#    '2024-07-10': None,
#    '2024-07-11': None,
#    '2024-07-12': {'mileage': 264.64},
#    '2024-07-13': {'mileage': 248.17},
#    '2024-07-14': {'mileage': 242.76},
#    '2024-07-15': {'mileage': 245.23},
#    '2024-07-16': {'mileage': 264.37},
#    '2024-07-17': {'mileage': 0.0},
#    '2024-07-18': {'mileage': 259.52},
#    '2024-07-19': {'mileage': 237.19},
#    '2024-07-20': {'mileage': 241.39},
#    '2024-07-21': {'mileage': 250.0},
#    '2024-07-22': {'mileage': 275.38},
#    '2024-07-23': {'mileage': 0.0},
#    '2024-07-24': None,
#    '2024-07-25': None},
#   '3036045': {'2024-06-26': {'mileage': 300.99},
#    '2024-06-27': {'mileage': 602.05},
#    '2024-06-28': {'mileage': 435.6},
#    '2024-06-29': {'mileage': 467.2},
#    '2024-06-30': {'mileage': 601.98},
#    '2024-07-01': {'mileage': 301.03},
#    '2024-07-02': {'mileage': 902.89},
#    '2024-07-03': {'mileage': 301.01},
#    '2024-07-04': {'mileage': 602.0},
#    '2024-07-05': {'mileage': 451.0},
#    '2024-07-06': {'mileage': 451.96},
#    '2024-07-07': {'mileage': 602.02},
#    '2024-07-08': {'mileage': 343.47},
#    '2024-07-09': {'mileage': 244.16},
#    '2024-07-10': None,
#    '2024-07-11': None,
#    '2024-07-12': {'mileage': 575.53},
#    '2024-07-13': {'mileage': 601.89},
#    '2024-07-14': {'mileage': 568.71},
#    '2024-07-15': {'mileage': 334.1},
#    '2024-07-16': {'mileage': 549.5},
#    '2024-07-17': {'mileage': 301.02},
#    '2024-07-18': {'mileage': 601.9},
#    '2024-07-19': {'mileage': 602.05},
#    '2024-07-20': {'mileage': 526.92},
#    '2024-07-21': {'mileage': 376.18},
#    '2024-07-22': {'mileage': 602.07},
#    '2024-07-23': {'mileage': 0.0},
#    '2024-07-24': None,
#    '2024-07-25': None},
#   '877768': {'2024-06-26': {'mileage': 810.27},
#    '2024-06-27': {'mileage': 822.62},
#    '2024-06-28': {'mileage': 845.2},
#    '2024-06-29': {'mileage': 812.86},
#    '2024-06-30': {'mileage': 828.67},
#    '2024-07-01': {'mileage': 835.58},
#    '2024-07-02': {'mileage': 844.09},
#    '2024-07-03': {'mileage': 804.39},
#    '2024-07-04': {'mileage': 847.61},
#    '2024-07-05': {'mileage': 799.25},
#    '2024-07-06': {'mileage': 816.75},
#    '2024-07-07': {'mileage': 824.8},
#    '2024-07-08': {'mileage': 799.34},
#    '2024-07-09': {'mileage': 140.25},
#    '2024-07-10': None,
#    '2024-07-11': None,
#    '2024-07-12': {'mileage': 592.19},
#    '2024-07-13': {'mileage': 854.3},
#    '2024-07-14': {'mileage': 818.32},
#    '2024-07-15': {'mileage': 790.81},
#    '2024-07-16': {'mileage': 620.34},
#    '2024-07-17': {'mileage': 220.53},
#    '2024-07-18': {'mileage': 638.4},
#    '2024-07-19': {'mileage': 826.04},
#    '2024-07-20': {'mileage': 778.5},
#    '2024-07-21': {'mileage': 816.49},
#    '2024-07-22': {'mileage': 801.53},
#    '2024-07-23': {'mileage': 136.54},
#    '2024-07-24': None,
#    '2024-07-25': None},
#   '3036043': {'2024-06-26': {'mileage': 302.33},
#    '2024-06-27': {'mileage': 291.36},
#    '2024-06-28': {'mileage': 286.36},
#    '2024-06-29': {'mileage': 269.82},
#    '2024-06-30': {'mileage': 267.09},
#    '2024-07-01': {'mileage': 310.93},
#    '2024-07-02': {'mileage': 303.22},
#    '2024-07-03': {'mileage': 299.53},
#    '2024-07-04': {'mileage': 299.93},
#    '2024-07-05': {'mileage': 309.53},
#    '2024-07-06': {'mileage': 309.58},
#    '2024-07-07': {'mileage': 294.25},
#    '2024-07-08': {'mileage': 305.21},
#    '2024-07-09': {'mileage': 84.47},
#    '2024-07-10': None,
#    '2024-07-11': None,
#    '2024-07-12': {'mileage': 160.04},
#    '2024-07-13': {'mileage': 312.89},
#    '2024-07-14': {'mileage': 277.58},
#    '2024-07-15': {'mileage': 264.43},
#    '2024-07-16': {'mileage': 174.91},
#    '2024-07-17': {'mileage': 120.44},
#    '2024-07-18': {'mileage': 208.07},
#    '2024-07-19': {'mileage': 297.46},
#    '2024-07-20': {'mileage': 280.78},
#    '2024-07-21': {'mileage': 283.42},
#    '2024-07-22': {'mileage': 298.95},
#    '2024-07-23': {'mileage': 73.94},
#    '2024-07-24': None,
#    '2024-07-25': None},
#   '3036070': {'2024-06-26': {'mileage': 165.96},
#    '2024-06-27': {'mileage': 159.98},
#    '2024-06-28': {'mileage': 164.31},
#    '2024-06-29': {'mileage': 179.04},
#    '2024-06-30': {'mileage': 199.18},
#    '2024-07-01': {'mileage': 171.95},
#    '2024-07-02': {'mileage': 177.35},
#    '2024-07-03': {'mileage': 201.19},
#    '2024-07-04': {'mileage': 195.94},
#    '2024-07-05': {'mileage': 168.82},
#    '2024-07-06': {'mileage': 174.16},
#    '2024-07-07': {'mileage': 162.56},
#    '2024-07-08': {'mileage': 173.85},
#    '2024-07-09': {'mileage': 0.0},
#    '2024-07-10': None,
#    '2024-07-11': None,
#    '2024-07-12': {'mileage': 174.88},
#    '2024-07-13': {'mileage': 174.29},
#    '2024-07-14': {'mileage': 159.71},
#    '2024-07-15': {'mileage': 185.29},
#    '2024-07-16': {'mileage': 145.72},
#    '2024-07-17': {'mileage': 0.0},
#    '2024-07-18': {'mileage': 172.44},
#    '2024-07-19': {'mileage': 169.09},
#    '2024-07-20': {'mileage': 177.86},
#    '2024-07-21': {'mileage': 174.36},
#    '2024-07-22': {'mileage': 190.02},
#    '2024-07-23': {'mileage': 0.0},
#    '2024-07-24': None,
#    '2024-07-25': None},
#   '3036071': {'2024-06-26': {'mileage': 272.57},
#    '2024-06-27': {'mileage': 220.36},
#    '2024-06-28': {'mileage': 255.96},
#    '2024-06-29': {'mileage': 245.26},
#    '2024-06-30': {'mileage': 255.36},
#    '2024-07-01': {'mileage': 248.13},
#    '2024-07-02': {'mileage': 247.93},
#    '2024-07-03': {'mileage': 226.05},
#    '2024-07-04': {'mileage': 264.14},
#    '2024-07-05': {'mileage': 230.5},
#    '2024-07-06': {'mileage': 259.19},
#    '2024-07-07': {'mileage': 256.84},
#    '2024-07-08': {'mileage': 242.64},
#    '2024-07-09': {'mileage': 0.0},
#    '2024-07-10': None,
#    '2024-07-11': None,
#    '2024-07-12': {'mileage': 232.24},
#    '2024-07-13': {'mileage': 231.56},
#    '2024-07-14': {'mileage': 249.25},
#    '2024-07-15': {'mileage': 249.13},
#    '2024-07-16': {'mileage': 4.8},
#    '2024-07-17': None,
#    '2024-07-18': {'mileage': 233.07},
#    '2024-07-19': {'mileage': 238.09},
#    '2024-07-20': {'mileage': 237.13},
#    '2024-07-21': {'mileage': 260.6},
#    '2024-07-22': {'mileage': 216.6},
#    '2024-07-23': {'mileage': 0.0},
#    '2024-07-24': None,
#    '2024-07-25': None},
#   '877767': {'2024-06-26': {'mileage': 851.69},
#    '2024-06-27': {'mileage': 870.19},
#    '2024-06-28': {'mileage': 838.06},
#    '2024-06-29': {'mileage': 870.38},
#    '2024-06-30': {'mileage': 851.76},
#    '2024-07-01': {'mileage': 862.61},
#    '2024-07-02': {'mileage': 896.83},
#    '2024-07-03': {'mileage': 839.15},
#    '2024-07-04': {'mileage': 854.86},
#    '2024-07-05': {'mileage': 873.94},
#    '2024-07-06': {'mileage': 893.86},
#    '2024-07-07': {'mileage': 851.79},
#    '2024-07-08': {'mileage': 886.27},
#    '2024-07-09': {'mileage': 142.27},
#    '2024-07-10': None,
#    '2024-07-11': None,
#    '2024-07-12': {'mileage': 671.81},
#    '2024-07-13': {'mileage': 879.79},
#    '2024-07-14': {'mileage': 849.21},
#    '2024-07-15': {'mileage': 860.92},
#    '2024-07-16': {'mileage': 661.62},
#    '2024-07-17': {'mileage': 225.4},
#    '2024-07-18': {'mileage': 735.15},
#    '2024-07-19': {'mileage': 876.93},
#    '2024-07-20': {'mileage': 862.68},
#    '2024-07-21': {'mileage': 850.79},
#    '2024-07-22': {'mileage': 858.62},
#    '2024-07-23': {'mileage': 156.29},
#    '2024-07-24': None,
#    '2024-07-25': None},
#   '3036068': {'2024-06-26': {'mileage': 383.9},
#    '2024-06-27': {'mileage': 390.72},
#    '2024-06-28': {'mileage': 369.03},
#    '2024-06-29': {'mileage': 382.75},
#    '2024-06-30': {'mileage': 379.09},
#    '2024-07-01': {'mileage': 383.4},
#    '2024-07-02': {'mileage': 371.47},
#    '2024-07-03': {'mileage': 395.12},
#    '2024-07-04': {'mileage': 383.36},
#    '2024-07-05': {'mileage': 393.41},
#    '2024-07-06': {'mileage': 367.02},
#    '2024-07-07': {'mileage': 371.13},
#    '2024-07-08': {'mileage': 369.44},
#    '2024-07-09': {'mileage': 110.32},
#    '2024-07-10': None,
#    '2024-07-11': None,
#    '2024-07-12': {'mileage': 226.31},
#    '2024-07-13': {'mileage': 357.71},
#    '2024-07-14': {'mileage': 358.86},
#    '2024-07-15': {'mileage': 388.63},
#    '2024-07-16': {'mileage': 297.68},
#    '2024-07-17': {'mileage': 162.43},
#    '2024-07-18': {'mileage': 264.82},
#    '2024-07-19': {'mileage': 367.04},
#    '2024-07-20': {'mileage': 386.19},
#    '2024-07-21': {'mileage': 363.85},
#    '2024-07-22': {'mileage': 384.34},
#    '2024-07-23': {'mileage': 92.16},
#    '2024-07-24': None,
#    '2024-07-25': None},
#   '877766': {'2024-06-26': {'mileage': 725.21},
#    '2024-06-27': {'mileage': 752.08},
#    '2024-06-28': {'mileage': 753.24},
#    '2024-06-29': {'mileage': 814.87},
#    '2024-06-30': {'mileage': 742.0},
#    '2024-07-01': {'mileage': 716.18},
#    '2024-07-02': {'mileage': 792.79},
#    '2024-07-03': {'mileage': 747.76},
#    '2024-07-04': {'mileage': 762.21},
#    '2024-07-05': {'mileage': 759.78},
#    '2024-07-06': {'mileage': 743.72},
#    '2024-07-07': {'mileage': 810.84},
#    '2024-07-08': {'mileage': 799.25},
#    '2024-07-09': {'mileage': 132.71},
#    '2024-07-10': None,
#    '2024-07-11': None,
#    '2024-07-12': {'mileage': 570.36},
#    '2024-07-13': {'mileage': 764.54},
#    '2024-07-14': {'mileage': 774.14},
#    '2024-07-15': {'mileage': 738.39},
#    '2024-07-16': {'mileage': 625.55},
#    '2024-07-17': {'mileage': 216.42},
#    '2024-07-18': {'mileage': 600.19},
#    '2024-07-19': {'mileage': 780.51},
#    '2024-07-20': {'mileage': 746.49},
#    '2024-07-21': {'mileage': 744.4},
#    '2024-07-22': {'mileage': 750.14},
#    '2024-07-23': {'mileage': 138.7},
#    '2024-07-24': None,
#    '2024-07-25': None},
#   '3036069': {'2024-06-26': {'mileage': 837.9},
#    '2024-06-27': {'mileage': 955.1},
#    '2024-06-28': {'mileage': 973.23},
#    '2024-06-29': {'mileage': 954.85},
#    '2024-06-30': {'mileage': 744.3},
#    '2024-07-01': {'mileage': 744.3},
#    '2024-07-02': {'mileage': 744.37},
#    '2024-07-03': {'mileage': 861.52},
#    '2024-07-04': {'mileage': 934.81},
#    '2024-07-05': {'mileage': 998.28},
#    '2024-07-06': {'mileage': 926.33},
#    '2024-07-07': {'mileage': 744.2},
#    '2024-07-08': {'mileage': 1075.85},
#    '2024-07-09': {'mileage': 0.0},
#    '2024-07-10': None,
#    '2024-07-11': None,
#    '2024-07-12': {'mileage': 1040.31},
#    '2024-07-13': {'mileage': 744.27},
#    '2024-07-14': {'mileage': 744.29},
#    '2024-07-15': {'mileage': 958.15},
#    '2024-07-16': {'mileage': 1235.33},
#    '2024-07-17': {'mileage': 0.0},
#    '2024-07-18': {'mileage': 1190.73},
#    '2024-07-19': {'mileage': 744.27},
#    '2024-07-20': {'mileage': 744.09},
#    '2024-07-21': {'mileage': 925.81},
#    '2024-07-22': {'mileage': 921.15},
#    '2024-07-23': {'mileage': 385.72},
#    '2024-07-24': None,
#    '2024-07-25': None},
#   '3036060': {'2024-06-26': {'mileage': 238.91},
#    '2024-06-27': {'mileage': 229.62},
#    '2024-06-28': {'mileage': 233.0},
#    '2024-06-29': {'mileage': 230.59},
#    '2024-06-30': {'mileage': 226.29},
#    '2024-07-01': {'mileage': 230.83},
#    '2024-07-02': {'mileage': 225.65},
#    '2024-07-03': {'mileage': 233.43},
#    '2024-07-04': {'mileage': 236.67},
#    '2024-07-05': {'mileage': 241.06},
#    '2024-07-06': {'mileage': 235.42},
#    '2024-07-07': {'mileage': 215.68},
#    '2024-07-08': {'mileage': 251.45},
#    '2024-07-09': {'mileage': 0.0},
#    '2024-07-10': None,
#    '2024-07-11': None,
#    '2024-07-12': {'mileage': 234.99},
#    '2024-07-13': {'mileage': 227.67},
#    '2024-07-14': {'mileage': 243.22},
#    '2024-07-15': {'mileage': 224.25},
#    '2024-07-16': {'mileage': 235.23},
#    '2024-07-17': {'mileage': 0.0},
#    '2024-07-18': {'mileage': 228.81},
#    '2024-07-19': {'mileage': 221.65},
#    '2024-07-20': {'mileage': 223.07},
#    '2024-07-21': {'mileage': 239.53},
#    '2024-07-22': {'mileage': 227.06},
#    '2024-07-23': {'mileage': 0.0},
#    '2024-07-24': None,
#    '2024-07-25': None},
#   '1228833': {'2024-06-26': {'mileage': 0.01},
#    '2024-06-27': {'mileage': 0.08},
#    '2024-06-28': {'mileage': 0.13},
#    '2024-06-29': {'mileage': 15.9},
#    '2024-06-30': {'mileage': 0.03},
#    '2024-07-01': {'mileage': 0.0},
#    '2024-07-02': {'mileage': 0.0},
#    '2024-07-03': {'mileage': 0.0},
#    '2024-07-04': {'mileage': 0.0},
#    '2024-07-05': {'mileage': 0.11},
#    '2024-07-06': {'mileage': 0.04},
#    '2024-07-07': {'mileage': 0.04},
#    '2024-07-08': {'mileage': 0.05},
#    '2024-07-09': {'mileage': 0.07},
#    '2024-07-10': {'mileage': 0.02},
#    '2024-07-11': {'mileage': 0.03},
#    '2024-07-12': {'mileage': 0.09},
#    '2024-07-13': {'mileage': 15.04},
#    '2024-07-14': {'mileage': 0.0},
#    '2024-07-15': {'mileage': 0.0},
#    '2024-07-16': {'mileage': 0.19},
#    '2024-07-17': {'mileage': 0.02},
#    '2024-07-18': {'mileage': 0.03},
#    '2024-07-19': {'mileage': 0.0},
#    '2024-07-20': {'mileage': 0.0},
#    '2024-07-21': {'mileage': 0.03},
#    '2024-07-22': {'mileage': 0.01},
#    '2024-07-23': {'mileage': 0.02},
#    '2024-07-24': {'mileage': 2.87},
#    '2024-07-25': {'mileage': 0.0}},
#   '3036059': {'2024-06-26': {'mileage': 142.81},
#    '2024-06-27': {'mileage': 171.73},
#    '2024-06-28': {'mileage': 153.89},
#    '2024-06-29': {'mileage': 150.49},
#    '2024-06-30': {'mileage': 161.03},
#    '2024-07-01': {'mileage': 170.91},
#    '2024-07-02': {'mileage': 191.36},
#    '2024-07-03': {'mileage': 168.83},
#    '2024-07-04': {'mileage': 151.58},
#    '2024-07-05': {'mileage': 162.13},
#    '2024-07-06': {'mileage': 162.49},
#    '2024-07-07': {'mileage': 170.14},
#    '2024-07-08': {'mileage': 160.77},
#    '2024-07-09': {'mileage': 0.0},
#    '2024-07-10': None,
#    '2024-07-11': None,
#    '2024-07-12': {'mileage': 196.5},
#    '2024-07-13': {'mileage': 177.34},
#    '2024-07-14': {'mileage': 162.18},
#    '2024-07-15': {'mileage': 164.29},
#    '2024-07-16': {'mileage': 161.92},
#    '2024-07-17': {'mileage': 0.0},
#    '2024-07-18': {'mileage': 184.49},
#    '2024-07-19': {'mileage': 148.98},
#    '2024-07-20': {'mileage': 171.34},
#    '2024-07-21': {'mileage': 185.0},
#    '2024-07-22': {'mileage': 159.83},
#    '2024-07-23': {'mileage': 0.0},
#    '2024-07-24': None,
#    '2024-07-25': None},
#   '3036056': {'2024-06-26': {'mileage': 344.44},
#    '2024-06-27': {'mileage': 343.65},
#    '2024-06-28': {'mileage': 329.21},
#    '2024-06-29': {'mileage': 332.27},
#    '2024-06-30': {'mileage': 319.3},
#    '2024-07-01': {'mileage': 364.5},
#    '2024-07-02': {'mileage': 368.69},
#    '2024-07-03': {'mileage': 338.33},
#    '2024-07-04': {'mileage': 308.41},
#    '2024-07-05': {'mileage': 303.16},
#    '2024-07-06': {'mileage': 352.56},
#    '2024-07-07': {'mileage': 358.92},
#    '2024-07-08': {'mileage': 351.39},
#    '2024-07-09': {'mileage': 102.09},
#    '2024-07-10': None,
#    '2024-07-11': None,
#    '2024-07-12': {'mileage': 165.85},
#    '2024-07-13': {'mileage': 333.01},
#    '2024-07-14': {'mileage': 344.53},
#    '2024-07-15': {'mileage': 343.24},
#    '2024-07-16': {'mileage': 214.51},
#    '2024-07-17': {'mileage': 151.41},
#    '2024-07-18': {'mileage': 242.13},
#    '2024-07-19': {'mileage': 367.88},
#    '2024-07-20': {'mileage': 359.19},
#    '2024-07-21': {'mileage': 358.44},
#    '2024-07-22': {'mileage': 351.85},
#    '2024-07-23': {'mileage': 92.0},
#    '2024-07-24': None,
#    '2024-07-25': None},
#   '3036057': {'2024-06-26': {'mileage': 1023.01},
#    '2024-06-27': {'mileage': 1155.84},
#    '2024-06-28': {'mileage': 1100.17},
#    '2024-06-29': {'mileage': 819.85},
#    '2024-06-30': {'mileage': 819.86},
#    '2024-07-01': {'mileage': 819.86},
#    '2024-07-02': {'mileage': 1330.81},
#    '2024-07-03': {'mileage': 1050.74},
#    '2024-07-04': {'mileage': 1155.8},
#    '2024-07-05': {'mileage': 1072.57},
#    '2024-07-06': {'mileage': 819.84},
#    '2024-07-07': {'mileage': 819.89},
#    '2024-07-08': {'mileage': 1531.56},
#    '2024-07-09': {'mileage': 0.0},
#    '2024-07-10': None,
#    '2024-07-11': None,
#    '2024-07-12': {'mileage': 1143.88},
#    '2024-07-13': {'mileage': 819.88},
#    '2024-07-14': {'mileage': 920.08},
#    '2024-07-15': {'mileage': 1153.53},
#    '2024-07-16': {'mileage': 1205.77},
#    '2024-07-17': {'mileage': 0.0},
#    '2024-07-18': {'mileage': 1385.05},
#    '2024-07-19': {'mileage': 819.86},
#    '2024-07-20': {'mileage': 887.61},
#    '2024-07-21': {'mileage': 1164.18},
#    '2024-07-22': {'mileage': 1166.2},
#    '2024-07-23': {'mileage': 61.46},
#    '2024-07-24': None,
#    '2024-07-25': None},
#   '3036049': {'2024-06-26': {'mileage': 262.4},
#    '2024-06-27': {'mileage': 275.8},
#    '2024-06-28': {'mileage': 269.74},
#    '2024-06-29': {'mileage': 279.93},
#    '2024-06-30': {'mileage': 260.56},
#    '2024-07-01': {'mileage': 269.59},
#    '2024-07-02': {'mileage': 298.93},
#    '2024-07-03': {'mileage': 256.83},
#    '2024-07-04': {'mileage': 277.33},
#    '2024-07-05': {'mileage': 259.47},
#    '2024-07-06': {'mileage': 280.49},
#    '2024-07-07': {'mileage': 265.69},
#    '2024-07-08': {'mileage': 275.93},
#    '2024-07-09': {'mileage': 0.0},
#    '2024-07-10': None,
#    '2024-07-11': None,
#    '2024-07-12': {'mileage': 275.7},
#    '2024-07-13': {'mileage': 264.19},
#    '2024-07-14': {'mileage': 262.79},
#    '2024-07-15': {'mileage': 273.73},
#    '2024-07-16': {'mileage': 291.88},
#    '2024-07-17': {'mileage': 0.0},
#    '2024-07-18': {'mileage': 268.52},
#    '2024-07-19': {'mileage': 265.29},
#    '2024-07-20': {'mileage': 264.12},
#    '2024-07-21': {'mileage': 287.75},
#    '2024-07-22': {'mileage': 269.22},
#    '2024-07-23': {'mileage': 0.0},
#    '2024-07-24': None,
#    '2024-07-25': None}},
#  'limit_exceeded': False,
#  'success': True}

# %%
dfm = pd.DataFrame.from_dict(mileage['result'], orient='index')
with pd.option_context("display.max_columns", 100, 'display.max_colwidth', 100):
    display(dfm.head(2))
# Out:
#                   2024-06-26           2024-06-27           2024-06-28  \
# 3036047  {'mileage': 252.43}  {'mileage': 252.63}  {'mileage': 246.38}
# 3036045  {'mileage': 300.99}  {'mileage': 602.05}   {'mileage': 435.6}
#
#                   2024-06-29           2024-06-30           2024-07-01  \
# 3036047  {'mileage': 257.19}   {'mileage': 246.0}  {'mileage': 256.98}
# 3036045   {'mileage': 467.2}  {'mileage': 601.98}  {'mileage': 301.03}
#
#                   2024-07-02           2024-07-03           2024-07-04  \
# 3036047  {'mileage': 269.11}   {'mileage': 260.5}  {'mileage': 260.71}
# 3036045  {'mileage': 902.89}  {'mileage': 301.01}   {'mileage': 602.0}
#
#                   2024-07-05           2024-07-06           2024-07-07  \
# 3036047  {'mileage': 260.72}  {'mileage': 264.85}  {'mileage': 269.94}
# 3036045   {'mileage': 451.0}  {'mileage': 451.96}  {'mileage': 602.02}
#
#                   2024-07-08           2024-07-09 2024-07-10 2024-07-11  \
# 3036047   {'mileage': 265.6}     {'mileage': 0.0}       None       None
# 3036045  {'mileage': 343.47}  {'mileage': 244.16}       None       None
#
#                   2024-07-12           2024-07-13           2024-07-14  \
# 3036047  {'mileage': 264.64}  {'mileage': 248.17}  {'mileage': 242.76}
# 3036045  {'mileage': 575.53}  {'mileage': 601.89}  {'mileage': 568.71}
#
#                   2024-07-15           2024-07-16           2024-07-17  \
# 3036047  {'mileage': 245.23}  {'mileage': 264.37}     {'mileage': 0.0}
# 3036045   {'mileage': 334.1}   {'mileage': 549.5}  {'mileage': 301.02}
#
#                   2024-07-18           2024-07-19           2024-07-20  \
# 3036047  {'mileage': 259.52}  {'mileage': 237.19}  {'mileage': 241.39}
# 3036045   {'mileage': 601.9}  {'mileage': 602.05}  {'mileage': 526.92}
#
#                   2024-07-21           2024-07-22        2024-07-23  \
# 3036047   {'mileage': 250.0}  {'mileage': 275.38}  {'mileage': 0.0}
# 3036045  {'mileage': 376.18}  {'mileage': 602.07}  {'mileage': 0.0}
#
#         2024-07-24 2024-07-25
# 3036047       None       None
# 3036045       None       None

# %%
def get_mileage(x) -> float:
    if x is not None:
        for k,v in x.items():
            return v
    return None
dfm = dfm.map(lambda x: get_mileage(x)).reset_index().rename(columns={'index':'tracker_id'})

# %%
dfm.melt(id_vars=["tracker_id"], var_name="date").rename(columns={'value':'mileage'}).to_csv('data/mileage.csv', index=False)

# %%
url = "https://api.eu.navixy.com/v2/tracker/get_diagnostics"

track_lists = []

for tracker_id in tracker.id.to_list(): 
    json_data = {
        'hash': 'feed000000000000000000000000cafe',
        'tracker_id': tracker_id,
        "from": "2024-06-26 00:00:00", 
        "to": "2024-07-26 00:00:00",
    }
    response = requests.post(url, headers=headers, json=json_data)
    df = pd.json_normalize(response.json()['list'])
    df['tracker_id'] = tracker_id
    track_lists.append(df)

df = pd.concat(track_lists, axis=0, ignore_index=True)
df.to_csv('data/track.csv', index=False)

# %%
url = "https://api.eu.navixy.com/v2/track/list"

track_lists = []

for tracker_id in tracker.id.to_list(): 
    json_data = {
        'hash': 'feed000000000000000000000000cafe',
        'tracker_id': tracker_id,
        "from": "2024-06-26 00:00:00", 
        "to": "2024-07-26 00:00:00",
    }
    response = requests.post(url, headers=headers, json=json_data)
    df = pd.json_normalize(response.json()['list'])
    df['tracker_id'] = tracker_id
    track_lists.append(df)

df = pd.concat(track_lists, axis=0, ignore_index=True)
df.to_csv('data/track.csv', index=False)

# %%
df.tracker_id.nunique()
# Out:
# 14

# %%
df.tracker_id.value_counts()
# Out:
# tracker_id
# 877768     1628
# 3036043    1241
# 3036056    1126
# 877766     1012
# 3036068     984
# 3036070     955
# 3036060     767
# 3036047     659
# 3036071     565
# 3036049     553
# 877767      450
# 3036069      86
# 3036057      60
# 3036045      39
# Name: count, dtype: int64

# %%
set(tracker.id.to_list()).difference(set(df.tracker_id.to_list()))
# Out:
# {1228833, 3036059}

# %%
dfm = dfm.melt(id_vars=["tracker_id"], var_name="date").rename(columns={'value':'mileage'})

# %%
dfm.groupby(['tracker_id'])['mileage'].sum()
# Out:
# tracker_id
# 1228833       34.81
# 3036043     6686.52
# 3036045    12247.23
# 3036047     5891.69
# 3036049     6255.88
# 3036056     7840.96
# 3036057    24247.30
# 3036059     3830.03
# 3036060     5334.08
# 3036068     8700.18
# 3036069    21129.16
# 3036070     4017.95
# 3036071     5377.40
# 877766     17502.47
# 877767     19872.87
# 877768     18725.67
# Name: mileage, dtype: float64

# %%
url = "https://api.eu.navixy.com/v2/tracker/get_readings"

json_data = {
    'hash': 'feed000000000000000000000000cafe',
    'tracker_id': tracker.id.to_list()[8],
}
response = requests.post(url, headers=headers, json=json_data)
response.json()
# Out:
# {'user_time': '2024-08-01 19:35:34',
#  'inputs': [{'label': 'Board voltage',
#    'units': '',
#    'name': 'board_voltage',
#    'type': 'power',
#    'value': 24.9,
#    'units_type': 'volt',
#    'converted_units_type': None,
#    'converted_value': None},
#   {'label': 'External temperature',
#    'units': '°С',
#    'name': 'ext_temp_sensor_1',
#    'type': 'temperature',
#    'value': 7.9,
#    'units_type': 'celsius',
#    'converted_units_type': None,
#    'converted_value': None}],
#  'update_time': '2024-07-23 04:09:47',
#  'success': True}

# %%
df = pd.json_normalize(response.json())
df = df.explode('inputs')
# if pd.isna(df.loc[0, 'inputs']) == False:
#     df = pd.concat([df, df['inputs'].apply(pd.Series)], axis=1)
pd.isna(df.iloc[0, 1])
# Out:
# False

# %%
df
# Out:
#              user_time                                             inputs  \
# 0  2024-08-01 19:35:34  {'label': 'Board voltage', 'units': '', 'name'...
# 0  2024-08-01 19:35:34  {'label': 'External temperature', 'units': '°С...
#
#            update_time  success
# 0  2024-07-23 04:09:47     True
# 0  2024-07-23 04:09:47     True

# %%
df
# Out:
#              user_time                                             inputs  \
# 0  2024-08-01 16:18:32  {'label': 'Board voltage', 'units': '', 'name'...
# 0  2024-08-01 16:18:32  {'label': 'External temperature', 'units': '°С...
#
#            update_time  success
# 0  2024-07-23 04:09:47     True
# 0  2024-07-23 04:09:47     True

# %%
df
# Out:
#              user_time inputs update_time  success
# 0  2024-08-01 16:14:16     []        None     True

# %%
pd.isnull(df.at[0, 'inputs'])
# Out:
# True

# %%
response.json()
# Out:
# {'list': [{'id': 22469,
#    'start_date': '2024-07-01 00:07:27',
#    'avg_speed': 45,
#    'end_date': '2024-07-01 00:28:47',
#    'length': 16.14,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.74,
#    'type': 'regular',
#    'end_address': '34, Orchard Place, Hawthorne, New Jersey, United States, 07506',
#    'start_address': 'Preakness HIlls Country Club, 1050, Ratzer Road, Wayne, New Jersey, United States, 07470',
#    'points': 237},
#   {'id': 22470,
#    'start_date': '2024-07-01 00:37:53',
#    'avg_speed': 45,
#    'end_date': '2024-07-01 01:04:18',
#    'length': 19.7,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.35,
#    'type': 'regular',
#    'end_address': '88, Chadwick Court, Park Ridge, Bergen County, New Jersey, United States, 07656',
#    'start_address': '34, Orchard Place, Hawthorne, New Jersey, United States, 07506',
#    'points': 279},
#   {'id': 22471,
#    'start_date': '2024-07-01 01:13:24',
#    'avg_speed': 43,
#    'end_date': '2024-07-01 01:26:13',
#    'length': 9.15,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.56,
#    'type': 'regular',
#    'end_address': '740, Pascack Road, Paramus, New Jersey, United States, 07652',
#    'start_address': '88, Chadwick Court, Park Ridge, Bergen County, New Jersey, United States, 07656',
#    'points': 138},
#   {'id': 22472,
#    'start_date': '2024-07-01 01:35:20',
#    'avg_speed': 45,
#    'end_date': '2024-07-01 01:49:24',
#    'length': 10.44,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.77,
#    'type': 'regular',
#    'end_address': '158, Baker Avenue, Bergenfield, New Jersey, United States, 07621',
#    'start_address': '740, Pascack Road, Paramus, New Jersey, United States, 07652',
#    'points': 157},
#   {'id': 22473,
#    'start_date': '2024-07-01 01:58:30',
#    'avg_speed': 46,
#    'end_date': '2024-07-01 02:12:35',
#    'length': 10.69,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.82,
#    'type': 'regular',
#    'end_address': '43, Van Orden Road, Harrington Park, Bergen County, New Jersey, United States, 07640',
#    'start_address': '158, Baker Avenue, Bergenfield, New Jersey, United States, 07621',
#    'points': 159},
#   {'id': 22474,
#    'start_date': '2024-07-01 02:21:41',
#    'avg_speed': 44,
#    'end_date': '2024-07-01 02:46:21',
#    'length': 18.06,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.07,
#    'type': 'regular',
#    'end_address': '393, Ackerman Avenue, Glen Rock, New Jersey, United States, 07452',
#    'start_address': '43, Van Orden Road, Harrington Park, Bergen County, New Jersey, United States, 07640',
#    'points': 268},
#   {'id': 22475,
#    'start_date': '2024-07-01 02:55:32',
#    'avg_speed': 42,
#    'end_date': '2024-07-01 03:13:31',
#    'length': 12.57,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.14,
#    'type': 'regular',
#    'end_address': '79, High Street, Westwood, New Jersey, United States, 07675',
#    'start_address': '444, Ackerman Avenue, Glen Rock, New Jersey, United States, 07452',
#    'points': 196},
#   {'id': 22476,
#    'start_date': '2024-07-01 03:22:38',
#    'avg_speed': 42,
#    'end_date': '2024-07-01 03:34:17',
#    'length': 8.22,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.4,
#    'type': 'regular',
#    'end_address': 'West Saddle River Road, Ho-Ho-Kus, Bergen County, New Jersey, United States, 07423',
#    'start_address': '79, High Street, Westwood, New Jersey, United States, 07675',
#    'points': 129},
#   {'id': 22477,
#    'start_date': '2024-07-01 03:43:23',
#    'avg_speed': 44,
#    'end_date': '2024-07-01 03:56:42',
#    'length': 9.68,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.65,
#    'type': 'regular',
#    'end_address': '394, Newtown Road, Wyckoff, New Jersey, United States, 07481',
#    'start_address': 'West Saddle River Road, Ho-Ho-Kus, Bergen County, New Jersey, United States, 07423',
#    'points': 147},
#   {'id': 22478,
#    'start_date': '2024-07-01 04:05:49',
#    'avg_speed': 43,
#    'end_date': '2024-07-01 04:17:13',
#    'length': 8.11,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.38,
#    'type': 'regular',
#    'end_address': '4th Avenue, Riverside, Paterson, New Jersey, United States, 07514',
#    'start_address': '394, Newtown Road, Wyckoff, New Jersey, United States, 07481',
#    'points': 125},
#   {'id': 22479,
#    'start_date': '2024-07-01 04:26:24',
#    'avg_speed': 41,
#    'end_date': '2024-07-01 04:37:09',
#    'length': 7.3,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.24,
#    'type': 'regular',
#    'end_address': '407, Berkshire Road, Ridgewood, New Jersey, United States, 07450',
#    'start_address': '4th Avenue, Riverside, Paterson, New Jersey, United States, 07514',
#    'points': 118},
#   {'id': 22480,
#    'start_date': '2024-07-01 04:46:15',
#    'avg_speed': 46,
#    'end_date': '2024-07-01 05:07:34',
#    'length': 16.23,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.76,
#    'type': 'regular',
#    'end_address': 'Madison Street, Passaic, New Jersey, United States, 07026',
#    'start_address': '407, Berkshire Road, Ridgewood, New Jersey, United States, 07450',
#    'points': 244},
#   {'id': 22481,
#    'start_date': '2024-07-01 05:16:46',
#    'avg_speed': 43,
#    'end_date': '2024-07-01 05:27:15',
#    'length': 7.6,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.29,
#    'type': 'regular',
#    'end_address': '237, Vreeland Avenue, Nutley, New Jersey, United States, 07110',
#    'start_address': 'Madison Street, Passaic, New Jersey, United States, 07026',
#    'points': 115},
#   {'id': 22482,
#    'start_date': '2024-07-01 05:36:21',
#    'avg_speed': 45,
#    'end_date': '2024-07-01 05:54:31',
#    'length': 13.72,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.33,
#    'type': 'regular',
#    'end_address': '32, Lincoln Avenue, Wood-Ridge, Bergen County, New Jersey, United States, 07075',
#    'start_address': '237, Vreeland Avenue, Nutley, New Jersey, United States, 07110',
#    'points': 199},
#   {'id': 22483,
#    'start_date': '2024-07-01 06:03:37',
#    'avg_speed': 45,
#    'end_date': '2024-07-01 06:22:21',
#    'length': 13.98,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.38,
#    'type': 'regular',
#    'end_address': '98, Sycamore Drive, Belleville, New Jersey, United States, 07109',
#    'start_address': '32, Lincoln Avenue, Wood-Ridge, Bergen County, New Jersey, United States, 07075',
#    'points': 202},
#   {'id': 22484,
#    'start_date': '2024-07-01 06:31:28',
#    'avg_speed': 44,
#    'end_date': '2024-07-01 06:50:32',
#    'length': 13.9,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.36,
#    'type': 'regular',
#    'end_address': '17, Longview Street, West Orange, New Jersey, United States, 07052',
#    'start_address': '98, Sycamore Drive, Belleville, New Jersey, United States, 07109',
#    'points': 210},
#   {'id': 22485,
#    'start_date': '2024-07-01 06:59:39',
#    'avg_speed': 42,
#    'end_date': '2024-07-01 07:10:48',
#    'length': 7.83,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.33,
#    'type': 'regular',
#    'end_address': 'New Jersey Institute of Technology, Summit Street, Newark, New Jersey, United States, 07102',
#    'start_address': '17, Longview Street, West Orange, New Jersey, United States, 07052',
#    'points': 128},
#   {'id': 22486,
#    'start_date': '2024-07-01 07:19:54',
#    'avg_speed': 43,
#    'end_date': '2024-07-01 07:43:04',
#    'length': 16.79,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.85,
#    'type': 'regular',
#    'end_address': '219, Fairview Avenue, Verona, New Jersey, United States, 07044',
#    'start_address': 'New Jersey Institute of Technology, Summit Street, Newark, New Jersey, United States, 07102',
#    'points': 244},
#   {'id': 22487,
#    'start_date': '2024-07-01 07:52:15',
#    'avg_speed': 45,
#    'end_date': '2024-07-01 08:13:25',
#    'length': 15.88,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.7,
#    'type': 'regular',
#    'end_address': '1-E Landfill, New Jersey Turnpike Western Spur, Kearny, New Jersey, United States, 07032',
#    'start_address': '219, Fairview Avenue, Verona, New Jersey, United States, 07044',
#    'points': 226},
#   {'id': 22488,
#    'start_date': '2024-07-01 08:22:31',
#    'avg_speed': 44,
#    'end_date': '2024-07-01 08:41:30',
#    'length': 13.88,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.36,
#    'type': 'regular',
#    'end_address': '170, Day Street, Bloomfield, New Jersey, United States, 07003',
#    'start_address': '1-E Landfill, New Jersey Turnpike Western Spur, Kearny, New Jersey, United States, 07032',
#    'points': 201},
#   {'id': 22489,
#    'start_date': '2024-07-01 08:50:37',
#    'avg_speed': 45,
#    'end_date': '2024-07-01 09:10:54',
#    'length': 15.19,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.58,
#    'type': 'regular',
#    'end_address': '68, Willow Street, Elmwood Park, New Jersey, United States, 07407',
#    'start_address': '170, Day Street, Bloomfield, New Jersey, United States, 07003',
#    'points': 226},
#   {'id': 22490,
#    'start_date': '2024-07-01 09:20:01',
#    'avg_speed': 45,
#    'end_date': '2024-07-01 09:43:50',
#    'length': 17.92,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.05,
#    'type': 'regular',
#    'end_address': '56, Bergenline Avenue, Westwood, New Jersey, United States, 07675',
#    'start_address': '68, Willow Street, Elmwood Park, New Jersey, United States, 07407',
#    'points': 265},
#   {'id': 22491,
#    'start_date': '2024-07-01 09:53:01',
#    'avg_speed': 41,
#    'end_date': '2024-07-01 10:05:01',
#    'length': 8.12,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.38,
#    'type': 'regular',
#    'end_address': '210, East Madison Avenue, Dumont, New Jersey, United States, 07628',
#    'start_address': '56, Bergenline Avenue, Westwood, New Jersey, United States, 07675',
#    'points': 132},
#   {'id': 22492,
#    'start_date': '2024-07-01 10:14:07',
#    'avg_speed': 44,
#    'end_date': '2024-07-01 10:27:52',
#    'length': 10.05,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.71,
#    'type': 'regular',
#    'end_address': '98, Laurel Court, Paramus, New Jersey, United States, 07652',
#    'start_address': '210, East Madison Avenue, Dumont, New Jersey, United States, 07628',
#    'points': 155},
#   {'id': 22493,
#    'start_date': '2024-07-01 10:36:58',
#    'avg_speed': 44,
#    'end_date': '2024-07-01 10:56:42',
#    'length': 14.49,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.46,
#    'type': 'regular',
#    'end_address': '196, East Union Avenue, East Rutherford, Bergen County, New Jersey, United States, 07073',
#    'start_address': '98, Laurel Court, Paramus, New Jersey, United States, 07652',
#    'points': 220},
#   {'id': 22494,
#    'start_date': '2024-07-01 11:05:53',
#    'avg_speed': 41,
#    'end_date': '2024-07-01 11:18:08',
#    'length': 8.43,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.43,
#    'type': 'regular',
#    'end_address': 'Lodi, New Jersey, United States, 07644',
#    'start_address': '196, East Union Avenue, East Rutherford, Bergen County, New Jersey, United States, 07073',
#    'points': 133},
#   {'id': 22495,
#    'start_date': '2024-07-01 11:27:14',
#    'avg_speed': 46,
#    'end_date': '2024-07-01 11:46:28',
#    'length': 14.8,
#    'max_speed': 58,
#    'norm_fuel_consumed': 2.52,
#    'type': 'regular',
#    'end_address': '44, Browertown Road, Little Falls, New Jersey, United States, 07424',
#    'start_address': 'Lodi, New Jersey, United States, 07644',
#    'points': 213},
#   {'id': 22496,
#    'start_date': '2024-07-01 11:55:35',
#    'avg_speed': 46,
#    'end_date': '2024-07-01 12:15:44',
#    'length': 15.3,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.6,
#    'type': 'regular',
#    'end_address': 'Rumba Cubana, 55, Becker Avenue, Rochelle Park, Bergen County, New Jersey, United States, 07662',
#    'start_address': '44, Browertown Road, Little Falls, New Jersey, United States, 07424',
#    'points': 237},
#   {'id': 22497,
#    'start_date': '2024-07-01 12:24:51',
#    'avg_speed': 44,
#    'end_date': '2024-07-01 12:38:40',
#    'length': 10.19,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.73,
#    'type': 'regular',
#    'end_address': '598, Barell Avenue, Carlstadt, Bergen County, New Jersey, United States, 07072',
#    'start_address': 'Rumba Cubana, 55, Becker Avenue, Rochelle Park, Bergen County, New Jersey, United States, 07662',
#    'points': 154},
#   {'id': 22498,
#    'start_date': '2024-07-01 12:47:46',
#    'avg_speed': 45,
#    'end_date': '2024-07-01 13:03:00',
#    'length': 11.43,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.94,
#    'type': 'regular',
#    'end_address': 'East Centre Street, Nutley, New Jersey, United States, 07110',
#    'start_address': '598, Barell Avenue, Carlstadt, Bergen County, New Jersey, United States, 07072',
#    'points': 167},
#   {'id': 22499,
#    'start_date': '2024-07-01 13:12:07',
#    'avg_speed': 46,
#    'end_date': '2024-07-01 13:41:57',
#    'length': 23.11,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.93,
#    'type': 'regular',
#    'end_address': '694, Queen Anne Road, Teaneck Township, New Jersey, United States, 07666',
#    'start_address': 'East Centre Street, Nutley, New Jersey, United States, 07110',
#    'points': 330},
#   {'id': 22500,
#    'start_date': '2024-07-01 13:51:03',
#    'avg_speed': 43,
#    'end_date': '2024-07-01 14:13:42',
#    'length': 16.31,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.77,
#    'type': 'regular',
#    'end_address': '57, William Street, Wallington, New Jersey, United States, 07057',
#    'start_address': '694, Queen Anne Road, Teaneck Township, New Jersey, United States, 07666',
#    'points': 248},
#   {'id': 22501,
#    'start_date': '2024-07-01 14:22:49',
#    'avg_speed': 44,
#    'end_date': '2024-07-01 14:45:38',
#    'length': 16.78,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.85,
#    'type': 'regular',
#    'end_address': '6, Lindbergh Boulevard, Teaneck Township, New Jersey, United States, 07666',
#    'start_address': '57, William Street, Wallington, New Jersey, United States, 07057',
#    'points': 253},
#   {'id': 22502,
#    'start_date': '2024-07-01 14:54:55',
#    'avg_speed': 43,
#    'end_date': '2024-07-01 15:15:24',
#    'length': 14.68,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.5,
#    'type': 'regular',
#    'end_address': 'Virgnia Drive, Fair Lawn, New Jersey, United States, 07653',
#    'start_address': '6, Lindbergh Boulevard, Teaneck Township, New Jersey, United States, 07666',
#    'points': 218},
#   {'id': 22503,
#    'start_date': '2024-07-01 15:29:35',
#    'avg_speed': 43,
#    'end_date': '2024-07-01 15:47:50',
#    'length': 13.23,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.25,
#    'type': 'regular',
#    'end_address': '22, Ellis Drive, North Haledon, Passaic County, New Jersey, United States, 07508',
#    'start_address': 'Virgnia Drive, Fair Lawn, New Jersey, United States, 07653',
#    'points': 196},
#   {'id': 22504,
#    'start_date': '2024-07-01 15:56:56',
#    'avg_speed': 45,
#    'end_date': '2024-07-01 16:27:31',
#    'length': 22.73,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.86,
#    'type': 'regular',
#    'end_address': '401, Bergen Avenue, Township of Washington, New Jersey, United States, 07676',
#    'start_address': '22, Ellis Drive, North Haledon, Passaic County, New Jersey, United States, 07508',
#    'points': 330},
#   {'id': 22505,
#    'start_date': '2024-07-01 16:36:37',
#    'avg_speed': 43,
#    'end_date': '2024-07-01 16:47:01',
#    'length': 7.4,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.26,
#    'type': 'regular',
#    'end_address': '87, Clinton Place, Woodcliff Lake, Bergen County, New Jersey, United States, 07677',
#    'start_address': '401, Bergen Avenue, Township of Washington, New Jersey, United States, 07676',
#    'points': 112},
#   {'id': 22506,
#    'start_date': '2024-07-01 16:56:13',
#    'avg_speed': 44,
#    'end_date': '2024-07-01 17:15:07',
#    'length': 13.86,
#    'max_speed': 58,
#    'norm_fuel_consumed': 2.36,
#    'type': 'regular',
#    'end_address': '168, Roosevelt Avenue, Dumont, New Jersey, United States, 07628',
#    'start_address': '87, Clinton Place, Woodcliff Lake, Bergen County, New Jersey, United States, 07677',
#    'points': 217},
#   {'id': 22507,
#    'start_date': '2024-07-01 17:24:14',
#    'avg_speed': 45,
#    'end_date': '2024-07-01 17:54:08',
#    'length': 22.35,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.8,
#    'type': 'regular',
#    'end_address': '85, Rosewood Court, North Haledon, Passaic County, New Jersey, United States, 07508',
#    'start_address': '168, Roosevelt Avenue, Dumont, New Jersey, United States, 07628',
#    'points': 321},
#   {'id': 22508,
#    'start_date': '2024-07-01 18:03:14',
#    'avg_speed': 40,
#    'end_date': '2024-07-01 18:17:25',
#    'length': 9.57,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.63,
#    'type': 'regular',
#    'end_address': '232, Northern Parkway, Ridgewood, New Jersey, United States, 07450',
#    'start_address': '85, Rosewood Court, North Haledon, Passaic County, New Jersey, United States, 07508',
#    'points': 154},
#   {'id': 22509,
#    'start_date': '2024-07-01 18:26:31',
#    'avg_speed': 46,
#    'end_date': '2024-07-01 18:50:55',
#    'length': 18.57,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.16,
#    'type': 'regular',
#    'end_address': 'Victory Memorial, Main Avenue, Clifton, New Jersey, United States, 07011',
#    'start_address': '232, Northern Parkway, Ridgewood, New Jersey, United States, 07450',
#    'points': 274},
#   {'id': 22510,
#    'start_date': '2024-07-01 19:00:01',
#    'avg_speed': 43,
#    'end_date': '2024-07-01 19:18:56',
#    'length': 13.48,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.29,
#    'type': 'regular',
#    'end_address': '240, South Mountain Avenue, Montclair, New Jersey, United States, 07042',
#    'start_address': 'Victory Memorial, Main Avenue, Clifton, New Jersey, United States, 07011',
#    'points': 212},
#   {'id': 22511,
#    'start_date': '2024-07-01 19:28:02',
#    'avg_speed': 43,
#    'end_date': '2024-07-01 19:42:31',
#    'length': 10.27,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.75,
#    'type': 'regular',
#    'end_address': '141, Sycamore Avenue, Livingston, New Jersey, United States, 07039',
#    'start_address': '240, South Mountain Avenue, Montclair, New Jersey, United States, 07042',
#    'points': 159},
#   {'id': 22512,
#    'start_date': '2024-07-01 19:51:42',
#    'avg_speed': 46,
#    'end_date': '2024-07-01 20:20:12',
#    'length': 22.01,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.74,
#    'type': 'regular',
#    'end_address': 'Valley Bank, 171, River Road, Nutley, New Jersey, United States, 07110',
#    'start_address': '141, Sycamore Avenue, Livingston, New Jersey, United States, 07039',
#    'points': 313},
#   {'id': 22513,
#    'start_date': '2024-07-01 20:29:23',
#    'avg_speed': 47,
#    'end_date': '2024-07-01 20:49:13',
#    'length': 15.63,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.66,
#    'type': 'regular',
#    'end_address': "GMA Sales, Michael Street, Zuckerberg's Industrial Park, Saddle Brook, New Jersey, United States, 07663",
#    'start_address': 'Valley Bank, 171, River Road, Nutley, New Jersey, United States, 07110',
#    'points': 231},
#   {'id': 22514,
#    'start_date': '2024-07-01 20:58:24',
#    'avg_speed': 46,
#    'end_date': '2024-07-01 21:25:19',
#    'length': 20.52,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.49,
#    'type': 'regular',
#    'end_address': '5447, Tonnelle Avenue, North Bergen, New Jersey, United States, 07047',
#    'start_address': "GMA Sales, Michael Street, Zuckerberg's Industrial Park, Saddle Brook, New Jersey, United States, 07663",
#    'points': 298},
#   {'id': 22515,
#    'start_date': '2024-07-01 21:34:30',
#    'avg_speed': 43,
#    'end_date': '2024-07-01 21:57:35',
#    'length': 16.41,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.79,
#    'type': 'regular',
#    'end_address': 'Freedom Way, Jersey City, New Jersey, United States, 07302',
#    'start_address': '5447, Tonnelle Avenue, North Bergen, New Jersey, United States, 07047',
#    'points': 250},
#   {'id': 22516,
#    'start_date': '2024-07-01 22:06:46',
#    'avg_speed': 46,
#    'end_date': '2024-07-01 22:35:51',
#    'length': 22.48,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.82,
#    'type': 'regular',
#    'end_address': '50, Rugby Avenue, New York, United States, 10301',
#    'start_address': 'Freedom Way, Jersey City, New Jersey, United States, 07302',
#    'points': 328},
#   {'id': 22517,
#    'start_date': '2024-07-01 22:44:57',
#    'avg_speed': 43,
#    'end_date': '2024-07-01 23:12:22',
#    'length': 19.72,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.35,
#    'type': 'regular',
#    'end_address': 'FedEx Cargo, Metroplex Road, Elizabeth, New Jersey, United States, 07201',
#    'start_address': '50, Rugby Avenue, New York, United States, 10301',
#    'points': 302},
#   {'id': 22518,
#    'start_date': '2024-07-01 23:21:28',
#    'avg_speed': 41,
#    'end_date': '2024-07-01 23:38:27',
#    'length': 11.59,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.97,
#    'type': 'regular',
#    'end_address': '610, Union Street, Linden, New Jersey, United States, 07036',
#    'start_address': 'FedEx Cargo, Metroplex Road, Elizabeth, New Jersey, United States, 07201',
#    'points': 182},
#   {'id': 22519,
#    'start_date': '2024-07-01 23:47:39',
#    'avg_speed': 46,
#    'end_date': '2024-07-02 00:09:43',
#    'length': 17.0,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.89,
#    'type': 'regular',
#    'end_address': '33, Leo Place, Newark, New Jersey, United States, 07108',
#    'start_address': '610, Union Street, Linden, New Jersey, United States, 07036',
#    'points': 246},
#   {'id': 22520,
#    'start_date': '2024-07-02 00:18:49',
#    'avg_speed': 40,
#    'end_date': '2024-07-02 00:30:19',
#    'length': 7.59,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.29,
#    'type': 'regular',
#    'end_address': 'Kellogg Street, Newark, New Jersey, United States, 07105',
#    'start_address': '33, Leo Place, Newark, New Jersey, United States, 07108',
#    'points': 127},
#   {'id': 22521,
#    'start_date': '2024-07-02 00:39:25',
#    'avg_speed': 42,
#    'end_date': '2024-07-02 01:06:30',
#    'length': 18.86,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.21,
#    'type': 'regular',
#    'end_address': '23, Wenlock Street, New York, United States, 10303',
#    'start_address': 'Kellogg Street, Newark, New Jersey, United States, 07105',
#    'points': 298},
#   {'id': 22522,
#    'start_date': '2024-07-02 01:15:36',
#    'avg_speed': 46,
#    'end_date': '2024-07-02 01:40:06',
#    'length': 18.62,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.17,
#    'type': 'regular',
#    'end_address': '1116, 42nd Street, New York, United States, 11219',
#    'start_address': '23, Wenlock Street, New York, United States, 10303',
#    'points': 277},
#   {'id': 22523,
#    'start_date': '2024-07-02 01:49:12',
#    'avg_speed': 45,
#    'end_date': '2024-07-02 02:19:07',
#    'length': 22.25,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.78,
#    'type': 'regular',
#    'end_address': '66, West 16th Road, New York, United States, 11693',
#    'start_address': '1116, 42nd Street, New York, United States, 11219',
#    'points': 326},
#   {'id': 22524,
#    'start_date': '2024-07-02 02:28:13',
#    'avg_speed': 44,
#    'end_date': '2024-07-02 02:52:48',
#    'length': 17.93,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.05,
#    'type': 'regular',
#    'end_address': '1220, Utica Avenue, Brooklyn Community District 17, New York, United States, 11203',
#    'start_address': '66, West 16th Road, New York, United States, 11693',
#    'points': 268},
#   {'id': 22525,
#    'start_date': '2024-07-02 03:01:59',
#    'avg_speed': 46,
#    'end_date': '2024-07-02 03:22:38',
#    'length': 15.78,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.68,
#    'type': 'regular',
#    'end_address': '196, Old Rockaway Boulevard, New York, United States, 11430',
#    'start_address': '1220, Utica Avenue, Brooklyn Community District 17, New York, United States, 11203',
#    'points': 225},
#   {'id': 22526,
#    'start_date': '2024-07-02 03:31:50',
#    'avg_speed': 45,
#    'end_date': '2024-07-02 03:47:04',
#    'length': 11.42,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.94,
#    'type': 'regular',
#    'end_address': '20, Newkirk Avenue, Village of East Rockaway, Town of Hempstead, New York, United States, 11518',
#    'start_address': '196, Old Rockaway Boulevard, New York, United States, 11430',
#    'points': 171},
#   {'id': 22527,
#    'start_date': '2024-07-02 03:56:10',
#    'avg_speed': 44,
#    'end_date': '2024-07-02 04:06:35',
#    'length': 7.63,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.3,
#    'type': 'regular',
#    'end_address': '325, Elm Street, West Hempstead, Town of Hempstead, New York, United States, 11552',
#    'start_address': '20, Newkirk Avenue, Village of East Rockaway, Town of Hempstead, New York, United States, 11518',
#    'points': 118},
#   {'id': 22528,
#    'start_date': '2024-07-02 04:15:45',
#    'avg_speed': 43,
#    'end_date': '2024-07-02 04:31:15',
#    'length': 11.06,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.88,
#    'type': 'regular',
#    'end_address': '706, Sherwood Street, South Valley Stream, Town of Hempstead, New York, United States, 11581',
#    'start_address': '325, Elm Street, West Hempstead, Town of Hempstead, New York, United States, 11552',
#    'points': 172},
#   {'id': 22529,
#    'start_date': '2024-07-02 04:52:08',
#    'avg_speed': 39,
#    'end_date': '2024-07-02 04:57:24',
#    'length': 3.38,
#    'max_speed': 57,
#    'norm_fuel_consumed': 0.57,
#    'type': 'regular',
#    'end_address': 'Northvale Public School, 441, Tappan Road, Northvale, New Jersey, United States, 07647',
#    'start_address': '264, Livingston Street, Norwood, Bergen County, New Jersey, United States, 07648',
#    'points': 57},
#   {'id': 22530,
#    'start_date': '2024-07-02 05:06:31',
#    'avg_speed': 43,
#    'end_date': '2024-07-02 05:17:33',
#    'length': 7.86,
#    'max_speed': 58,
#    'norm_fuel_consumed': 1.34,
#    'type': 'regular',
#    'end_address': 'Old Hook Road, Harrington Park, Bergen County, New Jersey, United States, 07640',
#    'start_address': 'Northvale Public School, 441, Tappan Road, Northvale, New Jersey, United States, 07647',
#    'points': 118},
#   {'id': 22531,
#    'start_date': '2024-07-02 05:26:42',
#    'avg_speed': 46,
#    'end_date': '2024-07-02 06:15:32',
#    'length': 37.09,
#    'max_speed': 59,
#    'norm_fuel_consumed': 6.31,
#    'type': 'regular',
#    'end_address': '10, Clement Street, City of Yonkers, New York, United States, 10710',
#    'start_address': 'Old Hook Road, Harrington Park, Bergen County, New Jersey, United States, 07640',
#    'points': 528},
#   {'id': 22532,
#    'start_date': '2024-07-02 06:24:39',
#    'avg_speed': 42,
#    'end_date': '2024-07-02 06:43:28',
#    'length': 13.05,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.22,
#    'type': 'regular',
#    'end_address': '210, Lincoln Avenue, Eastchester, New York, United States, 10709',
#    'start_address': '10, Clement Street, City of Yonkers, New York, United States, 10710',
#    'points': 206},
#   {'id': 22533,
#    'start_date': '2024-07-02 06:52:39',
#    'avg_speed': 47,
#    'end_date': '2024-07-02 07:41:40',
#    'length': 38.3,
#    'max_speed': 59,
#    'norm_fuel_consumed': 6.51,
#    'type': 'regular',
#    'end_address': '102, Hickory Lane, Closter, Bergen County, New Jersey, United States, 07624',
#    'start_address': '210, Lincoln Avenue, Eastchester, New York, United States, 10709',
#    'points': 534},
#   {'id': 22534,
#    'start_date': '2024-07-02 07:50:46',
#    'avg_speed': 45,
#    'end_date': '2024-07-02 08:08:31',
#    'length': 13.35,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.27,
#    'type': 'regular',
#    'end_address': '512, Floyd Street, Englewood Cliffs, Bergen County, New Jersey, United States, 07632',
#    'start_address': '102, Hickory Lane, Closter, Bergen County, New Jersey, United States, 07624',
#    'points': 197},
#   {'id': 22535,
#    'start_date': '2024-07-02 08:17:37',
#    'avg_speed': 44,
#    'end_date': '2024-07-02 08:35:31',
#    'length': 13.15,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.24,
#    'type': 'regular',
#    'end_address': 'Jacobo Villano Pardo, Riverside Walk, Upper West Side, New York, United States, 10025',
#    'start_address': '512, Floyd Street, Englewood Cliffs, Bergen County, New Jersey, United States, 07632',
#    'points': 197},
#   {'id': 22536,
#    'start_date': '2024-07-02 08:44:48',
#    'avg_speed': 44,
#    'end_date': '2024-07-02 09:11:33',
#    'length': 19.69,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.35,
#    'type': 'regular',
#    'end_address': '9, Laurel Avenue, Tenafly, New Jersey, United States, 07670',
#    'start_address': 'Jacobo Villano Pardo, Riverside Walk, Upper West Side, New York, United States, 10025',
#    'points': 300},
#   {'id': 22537,
#    'start_date': '2024-07-02 09:20:39',
#    'avg_speed': 44,
#    'end_date': '2024-07-02 09:48:39',
#    'length': 20.31,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.45,
#    'type': 'regular',
#    'end_address': 'Riverside Walk, New York, United States, 10025',
#    'start_address': '9, Laurel Avenue, Tenafly, New Jersey, United States, 07670',
#    'points': 305},
#   {'id': 22538,
#    'start_date': '2024-07-02 09:57:45',
#    'avg_speed': 41,
#    'end_date': '2024-07-02 10:16:14',
#    'length': 12.6,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.14,
#    'type': 'regular',
#    'end_address': '22-38, 38th Street, New York, United States, 11105',
#    'start_address': 'Riverside Walk, New York, United States, 10025',
#    'points': 195},
#   {'id': 22539,
#    'start_date': '2024-07-02 10:25:21',
#    'avg_speed': 45,
#    'end_date': '2024-07-02 10:41:25',
#    'length': 11.95,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.03,
#    'type': 'regular',
#    'end_address': "O'Brien Avenue, New York, United States, 10473",
#    'start_address': '22-38, 38th Street, New York, United States, 11105',
#    'points': 174},
#   {'id': 22540,
#    'start_date': '2024-07-02 10:50:32',
#    'avg_speed': 46,
#    'end_date': '2024-07-02 11:24:11',
#    'length': 25.94,
#    'max_speed': 59,
#    'norm_fuel_consumed': 4.41,
#    'type': 'regular',
#    'end_address': '227, Dock Lane, Village of Great Neck, Town of North Hempstead, New York, United States, 11024',
#    'start_address': "O'Brien Avenue, New York, United States, 10473",
#    'points': 374},
#   {'id': 22541,
#    'start_date': '2024-07-02 11:33:18',
#    'avg_speed': 46,
#    'end_date': '2024-07-02 12:20:28',
#    'length': 35.95,
#    'max_speed': 59,
#    'norm_fuel_consumed': 6.11,
#    'type': 'regular',
#    'end_address': 'Horace Mann School, 231, Waldo Avenue, New York, United States, 10471',
#    'start_address': '227, Dock Lane, Village of Great Neck, Town of North Hempstead, New York, United States, 11024',
#    'points': 526},
#   {'id': 22542,
#    'start_date': '2024-07-02 12:34:24',
#    'avg_speed': 44,
#    'end_date': '2024-07-02 12:58:44',
#    'length': 18.0,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.06,
#    'type': 'regular',
#    'end_address': '9198, Durham Avenue, North Bergen, New Jersey, United States, 07047',
#    'start_address': 'Horace Mann School, 231, Waldo Avenue, New York, United States, 10471',
#    'points': 271},
#   {'id': 22543,
#    'start_date': '2024-07-02 13:07:55',
#    'avg_speed': 43,
#    'end_date': '2024-07-02 13:31:25',
#    'length': 16.83,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.86,
#    'type': 'regular',
#    'end_address': 'New York, United States, 10451',
#    'start_address': '9198, Durham Avenue, North Bergen, New Jersey, United States, 07047',
#    'points': 257},
#   {'id': 22544,
#    'start_date': '2024-07-02 13:40:32',
#    'avg_speed': 43,
#    'end_date': '2024-07-02 14:25:42',
#    'length': 32.45,
#    'max_speed': 59,
#    'norm_fuel_consumed': 5.52,
#    'type': 'regular',
#    'end_address': 'Holland Tunnel, New York, United States, 10005',
#    'start_address': 'New York, United States, 10451',
#    'points': 505},
#   {'id': 22545,
#    'start_date': '2024-07-02 14:34:48',
#    'avg_speed': 40,
#    'end_date': '2024-07-02 15:07:13',
#    'length': 21.67,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.68,
#    'type': 'regular',
#    'end_address': 'Garden Street, Newark, New Jersey, United States, 07105',
#    'start_address': 'Holland Tunnel, New York, United States, 10005',
#    'points': 359},
#   {'id': 22546,
#    'start_date': '2024-07-02 15:16:20',
#    'avg_speed': 44,
#    'end_date': '2024-07-02 15:45:09',
#    'length': 21.15,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.6,
#    'type': 'regular',
#    'end_address': 'Metro Road East, Transco Pipeline, Carlstadt, Bergen County, New Jersey, United States, 97657',
#    'start_address': 'Garden Street, Newark, New Jersey, United States, 07105',
#    'points': 313},
#   {'id': 22547,
#    'start_date': '2024-07-02 15:54:20',
#    'avg_speed': 45,
#    'end_date': '2024-07-02 16:18:35',
#    'length': 18.0,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.06,
#    'type': 'regular',
#    'end_address': '29, Columbus Avenue, Montclair, New Jersey, United States, 07042',
#    'start_address': 'Metro Road East, Transco Pipeline, Carlstadt, Bergen County, New Jersey, United States, 97657',
#    'points': 270},
#   {'id': 22548,
#    'start_date': '2024-07-02 16:27:41',
#    'avg_speed': 44,
#    'end_date': '2024-07-02 16:50:01',
#    'length': 16.26,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.76,
#    'type': 'regular',
#    'end_address': '68, Avenue C, Haledon, Passaic County, New Jersey, United States, 07508',
#    'start_address': '29, Columbus Avenue, Montclair, New Jersey, United States, 07042',
#    'points': 244},
#   {'id': 22549,
#    'start_date': '2024-07-02 16:59:07',
#    'avg_speed': 45,
#    'end_date': '2024-07-02 17:20:22',
#    'length': 15.94,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.71,
#    'type': 'regular',
#    'end_address': '98, Albany Avenue, Nutley, New Jersey, United States, 07110',
#    'start_address': '68, Avenue C, Haledon, Passaic County, New Jersey, United States, 07508',
#    'points': 234},
#   {'id': 22550,
#    'start_date': '2024-07-02 17:29:33',
#    'avg_speed': 46,
#    'end_date': '2024-07-02 17:47:07',
#    'length': 13.48,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.29,
#    'type': 'regular',
#    'end_address': "Saint Bonaventure's Parish Hall, Ramsey Street, Paterson, New Jersey, United States, 07501",
#    'start_address': '98, Albany Avenue, Nutley, New Jersey, United States, 07110',
#    'points': 196},
#   {'id': 22551,
#    'start_date': '2024-07-02 17:56:14',
#    'avg_speed': 43,
#    'end_date': '2024-07-02 18:09:13',
#    'length': 9.2,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.56,
#    'type': 'regular',
#    'end_address': 'Yellow / Service Road [Link], North Haledon, Passaic County, New Jersey, United States, 07508',
#    'start_address': "Saint Bonaventure's Parish Hall, Ramsey Street, Paterson, New Jersey, United States, 07501",
#    'points': 138},
#   {'id': 22552,
#    'start_date': '2024-07-02 18:18:19',
#    'avg_speed': 42,
#    'end_date': '2024-07-02 18:31:19',
#    'length': 9.16,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.56,
#    'type': 'regular',
#    'end_address': '302, Elberon Avenue, Paterson, New Jersey, United States, 07502',
#    'start_address': 'Yellow / Service Road [Link], North Haledon, Passaic County, New Jersey, United States, 07508',
#    'points': 136},
#   {'id': 22553,
#    'start_date': '2024-07-02 18:40:25',
#    'avg_speed': 43,
#    'end_date': '2024-07-02 18:59:45',
#    'length': 13.98,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.38,
#    'type': 'regular',
#    'end_address': 'South Main Street Apartments, 44, South Main Street, Lodi, New Jersey, United States, 07644',
#    'start_address': '302, Elberon Avenue, Paterson, New Jersey, United States, 07502',
#    'points': 209},
#   {'id': 22554,
#    'start_date': '2024-07-02 19:08:51',
#    'avg_speed': 45,
#    'end_date': '2024-07-02 19:29:40',
#    'length': 15.52,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.64,
#    'type': 'regular',
#    'end_address': '30, Windsor Street, Kearny, New Jersey, United States, 07032',
#    'start_address': 'South Main Street Apartments, 44, South Main Street, Lodi, New Jersey, United States, 07644',
#    'points': 224},
#   {'id': 22555,
#    'start_date': '2024-07-02 19:38:52',
#    'avg_speed': 42,
#    'end_date': '2024-07-02 20:05:41',
#    'length': 18.93,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.22,
#    'type': 'regular',
#    'end_address': '30, Club Road, Montclair, New Jersey, United States, 07043',
#    'start_address': '30, Windsor Street, Kearny, New Jersey, United States, 07032',
#    'points': 299},
#   {'id': 22556,
#    'start_date': '2024-07-02 20:14:48',
#    'avg_speed': 44,
#    'end_date': '2024-07-02 20:31:07',
#    'length': 12.07,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.05,
#    'type': 'regular',
#    'end_address': 'Cary Avenue, North Arlington, New Jersey, United States, 07031',
#    'start_address': '30, Club Road, Montclair, New Jersey, United States, 07043',
#    'points': 179},
#   {'id': 22557,
#    'start_date': '2024-07-02 20:40:18',
#    'avg_speed': 43,
#    'end_date': '2024-07-02 21:04:03',
#    'length': 16.85,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.86,
#    'type': 'regular',
#    'end_address': 'New Jersey Turnpike Western Spur, Kearny, New Jersey, United States, 07032',
#    'start_address': 'Cary Avenue, North Arlington, New Jersey, United States, 07031',
#    'points': 252},
#   {'id': 22558,
#    'start_date': '2024-07-02 21:13:09',
#    'avg_speed': 42,
#    'end_date': '2024-07-02 21:33:24',
#    'length': 14.34,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.44,
#    'type': 'regular',
#    'end_address': '33, Freeman Avenue, East Orange, New Jersey, United States, 07018',
#    'start_address': 'New Jersey Turnpike Western Spur, Kearny, New Jersey, United States, 07032',
#    'points': 229},
#   {'id': 22559,
#    'start_date': '2024-07-02 21:42:29',
#    'avg_speed': 46,
#    'end_date': '2024-07-02 22:03:25',
#    'length': 16.04,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.73,
#    'type': 'regular',
#    'end_address': '179, 3rd Avenue, Roselle, New Jersey, United States, 07203',
#    'start_address': '33, Freeman Avenue, East Orange, New Jersey, United States, 07018',
#    'points': 225},
#   {'id': 22560,
#    'start_date': '2024-07-02 22:12:31',
#    'avg_speed': 42,
#    'end_date': '2024-07-02 22:34:36',
#    'length': 15.37,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.61,
#    'type': 'regular',
#    'end_address': 'Oak Island Yard, New Jersey Turnpike Newark Bay Extension, Newark, New Jersey, United States, 07105',
#    'start_address': '179, 3rd Avenue, Roselle, New Jersey, United States, 07203',
#    'points': 237},
#   {'id': 22561,
#    'start_date': '2024-07-02 22:43:42',
#    'avg_speed': 45,
#    'end_date': '2024-07-02 23:18:17',
#    'length': 26.1,
#    'max_speed': 59,
#    'norm_fuel_consumed': 4.44,
#    'type': 'regular',
#    'end_address': '32, Pleasant Avenue, Montclair, New Jersey, United States, 07042',
#    'start_address': 'Oak Island Yard, New Jersey Turnpike Newark Bay Extension, Newark, New Jersey, United States, 07105',
#    'points': 382},
#   {'id': 22562,
#    'start_date': '2024-07-02 23:27:23',
#    'avg_speed': 46,
#    'end_date': '2024-07-02 23:49:53',
#    'length': 17.15,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.92,
#    'type': 'regular',
#    'end_address': '2785, Larchmont Road, Union, New Jersey, United States, 07083',
#    'start_address': '32, Pleasant Avenue, Montclair, New Jersey, United States, 07042',
#    'points': 245},
#   {'id': 22563,
#    'start_date': '2024-07-02 23:59:04',
#    'avg_speed': 43,
#    'end_date': '2024-07-03 00:10:28',
#    'length': 8.14,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.38,
#    'type': 'regular',
#    'end_address': 'Checo Mini Market, Saint James Place, Newark, New Jersey, United States, 07112',
#    'start_address': '2785, Larchmont Road, Union, New Jersey, United States, 07083',
#    'points': 123},
#   {'id': 22564,
#    'start_date': '2024-07-03 00:19:34',
#    'avg_speed': 46,
#    'end_date': '2024-07-03 00:38:14',
#    'length': 14.46,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.46,
#    'type': 'regular',
#    'end_address': 'Lineage, 100, Industrial Drive, Jersey City, New Jersey, United States, 07305',
#    'start_address': 'Checo Mini Market, Saint James Place, Newark, New Jersey, United States, 07112',
#    'points': 213},
#   {'id': 22565,
#    'start_date': '2024-07-03 00:47:20',
#    'avg_speed': 43,
#    'end_date': '2024-07-03 01:18:05',
#    'length': 21.8,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.71,
#    'type': 'regular',
#    'end_address': '1311, Pacific Street, New York, United States, 11216',
#    'start_address': 'Lineage, 100, Industrial Drive, Jersey City, New Jersey, United States, 07305',
#    'points': 334},
#   {'id': 22566,
#    'start_date': '2024-07-03 01:27:16',
#    'avg_speed': 43,
#    'end_date': '2024-07-03 01:49:41',
#    'length': 16.02,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.72,
#    'type': 'regular',
#    'end_address': '141-11, Union Turnpike, New York, United States, 11367',
#    'start_address': '1311, Pacific Street, New York, United States, 11216',
#    'points': 245},
#   {'id': 22567,
#    'start_date': '2024-07-03 01:58:47',
#    'avg_speed': 44,
#    'end_date': '2024-07-03 02:22:02',
#    'length': 17.08,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.9,
#    'type': 'regular',
#    'end_address': '5, Raisig Avenue, Village of Valley Stream, Town of Hempstead, New York, United States, 11580',
#    'start_address': '141-11, Union Turnpike, New York, United States, 11367',
#    'points': 254},
#   {'id': 22568,
#    'start_date': '2024-07-03 02:31:08',
#    'avg_speed': 43,
#    'end_date': '2024-07-03 02:42:48',
#    'length': 8.32,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.41,
#    'type': 'regular',
#    'end_address': 'North Boundary Road, New York, United States, 11430',
#    'start_address': '5, Raisig Avenue, Village of Valley Stream, Town of Hempstead, New York, United States, 11580',
#    'points': 126},
#   {'id': 22569,
#    'start_date': '2024-07-03 02:51:59',
#    'avg_speed': 41,
#    'end_date': '2024-07-03 03:11:43',
#    'length': 13.45,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.29,
#    'type': 'regular',
#    'end_address': '808, Shad Creek Road, New York, United States, 11693',
#    'start_address': 'North Boundary Road, New York, United States, 11430',
#    'points': 220},
#   {'id': 22570,
#    'start_date': '2024-07-03 03:20:49',
#    'avg_speed': 43,
#    'end_date': '2024-07-03 03:36:39',
#    'length': 11.35,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.93,
#    'type': 'regular',
#    'end_address': 'Enterprise Avenue, New York, United States, 11694',
#    'start_address': '808, Shad Creek Road, New York, United States, 11693',
#    'points': 173},
#   {'id': 22571,
#    'start_date': '2024-07-03 03:45:50',
#    'avg_speed': 43,
#    'end_date': '2024-07-03 04:09:25',
#    'length': 16.96,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.88,
#    'type': 'regular',
#    'end_address': '63, Walnut Road, Inwood, Town of Hempstead, New York, United States, 11096',
#    'start_address': 'Enterprise Avenue, New York, United States, 11694',
#    'points': 258},
#   {'id': 22572,
#    'start_date': '2024-07-03 04:18:31',
#    'avg_speed': 45,
#    'end_date': '2024-07-03 04:44:26',
#    'length': 19.54,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.32,
#    'type': 'regular',
#    'end_address': '231, Belmont Avenue, New York, United States, 11207',
#    'start_address': '63, Walnut Road, Inwood, Town of Hempstead, New York, United States, 11096',
#    'points': 282},
#   {'id': 22573,
#    'start_date': '2024-07-03 04:53:37',
#    'avg_speed': 43,
#    'end_date': '2024-07-03 05:12:56',
#    'length': 13.76,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.34,
#    'type': 'regular',
#    'end_address': '4902, Laurel Hill Boulevard, New York, United States, 11377',
#    'start_address': '231, Belmont Avenue, New York, United States, 11207',
#    'points': 199},
#   {'id': 22574,
#    'start_date': '2024-07-03 05:22:03',
#    'avg_speed': 44,
#    'end_date': '2024-07-03 05:34:07',
#    'length': 8.94,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.52,
#    'type': 'regular',
#    'end_address': '19, Richmond Street, New York, United States, 11208',
#    'start_address': '4902, Laurel Hill Boulevard, New York, United States, 11377',
#    'points': 132},
#   {'id': 22575,
#    'start_date': '2024-07-03 05:43:13',
#    'avg_speed': 45,
#    'end_date': '2024-07-03 06:11:03',
#    'length': 20.76,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.53,
#    'type': 'regular',
#    'end_address': '100th Drive, New York, United States, 11429',
#    'start_address': '19, Richmond Street, New York, United States, 11208',
#    'points': 311},
#   {'id': 22576,
#    'start_date': '2024-07-03 06:20:09',
#    'avg_speed': 45,
#    'end_date': '2024-07-03 06:45:00',
#    'length': 18.78,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.19,
#    'type': 'regular',
#    'end_address': '31-99, 123rd Street, New York, United States, 11354',
#    'start_address': '100th Drive, New York, United States, 11429',
#    'points': 221},
#   {'id': 22577,
#    'start_date': '2024-07-03 06:54:08',
#    'avg_speed': 46,
#    'end_date': '2024-07-03 07:19:18',
#    'length': 19.3,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.28,
#    'type': 'regular',
#    'end_address': '33, South Tyson Avenue, Village of Floral Park, Town of Hempstead, New York, United States, 11001',
#    'start_address': '31-99, 123rd Street, New York, United States, 11354',
#    'points': 286},
#   {'id': 22578,
#    'start_date': '2024-07-03 07:28:29',
#    'avg_speed': 42,
#    'end_date': '2024-07-03 07:38:08',
#    'length': 6.74,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.15,
#    'type': 'regular',
#    'end_address': '197-58, Nashville Boulevard, New York, United States, 11413',
#    'start_address': '33, South Tyson Avenue, Village of Floral Park, Town of Hempstead, New York, United States, 11001',
#    'points': 109},
#   {'id': 22579,
#    'start_date': '2024-07-03 07:47:15',
#    'avg_speed': 43,
#    'end_date': '2024-07-03 08:16:09',
#    'length': 20.77,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.53,
#    'type': 'regular',
#    'end_address': 'Shore Front Parkway, New York, United States, 11694',
#    'start_address': '197-58, Nashville Boulevard, New York, United States, 11413',
#    'points': 317},
#   {'id': 22580,
#    'start_date': '2024-07-03 08:25:16',
#    'avg_speed': 43,
#    'end_date': '2024-07-03 08:46:35',
#    'length': 15.25,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.59,
#    'type': 'regular',
#    'end_address': '875, East 26th Street, New York, United States, 11210',
#    'start_address': 'Shore Front Parkway, New York, United States, 11694',
#    'points': 226},
#   {'id': 22581,
#    'start_date': '2024-07-03 08:55:42',
#    'avg_speed': 43,
#    'end_date': '2024-07-03 09:29:52',
#    'length': 24.22,
#    'max_speed': 59,
#    'norm_fuel_consumed': 4.12,
#    'type': 'regular',
#    'end_address': 'Caven Point Road, Jersey City, New Jersey, United States, 07305',
#    'start_address': '875, East 26th Street, New York, United States, 11210',
#    'points': 370},
#   {'id': 22582,
#    'start_date': '2024-07-03 09:38:58',
#    'avg_speed': 42,
#    'end_date': '2024-07-03 10:11:13',
#    'length': 22.69,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.86,
#    'type': 'regular',
#    'end_address': 'New Jersey Turnpike Western Spur, Lyndhurst, New Jersey, United States, 07031',
#    'start_address': 'Caven Point Road, Jersey City, New Jersey, United States, 07305',
#    'points': 348},
#   {'id': 22583,
#    'start_date': '2024-07-03 10:23:54',
#    'avg_speed': 42,
#    'end_date': '2024-07-03 10:45:19',
#    'length': 14.9,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.53,
#    'type': 'regular',
#    'end_address': '614, 17th Street, Union City, New Jersey, United States, 07087',
#    'start_address': 'New Jersey Turnpike Western Spur, Lyndhurst, New Jersey, United States, 07031',
#    'points': 239},
#   {'id': 22584,
#    'start_date': '2024-07-03 10:54:25',
#    'avg_speed': 43,
#    'end_date': '2024-07-03 11:19:14',
#    'length': 17.89,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.04,
#    'type': 'regular',
#    'end_address': 'George Washington Bridge, Trans-Manhattan Expressway, New York, United States, 10033',
#    'start_address': '614, 17th Street, Union City, New Jersey, United States, 07087',
#    'points': 276},
#   {'id': 22585,
#    'start_date': '2024-07-03 11:28:21',
#    'avg_speed': 45,
#    'end_date': '2024-07-03 12:00:26',
#    'length': 24.21,
#    'max_speed': 59,
#    'norm_fuel_consumed': 4.12,
#    'type': 'regular',
#    'end_address': 'New Jersey Turnpike Eastern Spur, Ridgefield, New Jersey, United States, 97657',
#    'start_address': 'George Washington Bridge, Trans-Manhattan Expressway, New York, United States, 10033',
#    'points': 355},
#   {'id': 22586,
#    'start_date': '2024-07-03 12:09:32',
#    'avg_speed': 41,
#    'end_date': '2024-07-03 12:33:37',
#    'length': 16.65,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.83,
#    'type': 'regular',
#    'end_address': 'Hoboken Newport Walkway- Hudson River Waterfront Walkway, Jersey City, New Jersey, United States, 07311',
# ...
#    'avg_speed': 44,
#    'end_date': '2024-07-22 06:05:47',
#    'length': 8.02,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.36,
#    'type': 'regular',
#    'end_address': '1433, Lincoln Place, New York, United States, 11213',
#    'start_address': '86-23, 102nd Avenue, New York, United States, 11416',
#    'points': 115},
#   {'id': 23217,
#    'start_date': '2024-07-22 06:14:56',
#    'avg_speed': 42,
#    'end_date': '2024-07-22 06:28:50',
#    'length': 9.82,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.67,
#    'type': 'regular',
#    'end_address': '156-13, 102nd Street, New York, United States, 11414',
#    'start_address': '1433, Lincoln Place, New York, United States, 11213',
#    'points': 151},
#   {'id': 23218,
#    'start_date': '2024-07-22 06:37:59',
#    'avg_speed': 42,
#    'end_date': '2024-07-22 06:52:08',
#    'length': 9.86,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.68,
#    'type': 'regular',
#    'end_address': '1593, Pacific Street, New York, United States, 11213',
#    'start_address': '156-13, 102nd Street, New York, United States, 11414',
#    'points': 152},
#   {'id': 23219,
#    'start_date': '2024-07-22 07:01:14',
#    'avg_speed': 44,
#    'end_date': '2024-07-22 07:24:34',
#    'length': 17.25,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.93,
#    'type': 'regular',
#    'end_address': '318, West 49th Street, New York, United States, 10019',
#    'start_address': '1593, Pacific Street, New York, United States, 11213',
#    'points': 256},
#   {'id': 23220,
#    'start_date': '2024-07-22 07:33:38',
#    'avg_speed': 46,
#    'end_date': '2024-07-22 07:49:38',
#    'length': 12.27,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.09,
#    'type': 'regular',
#    'end_address': '1001, Jerome Avenue, New York, United States, 10452',
#    'start_address': '318, West 49th Street, New York, United States, 10019',
#    'points': 179},
#   {'id': 23221,
#    'start_date': '2024-07-22 07:58:45',
#    'avg_speed': 45,
#    'end_date': '2024-07-22 08:30:52',
#    'length': 24.14,
#    'max_speed': 59,
#    'norm_fuel_consumed': 4.1,
#    'type': 'regular',
#    'end_address': 'Penhorn Avenue, Secaucus, New Jersey, United States, 07096',
#    'start_address': '1001, Jerome Avenue, New York, United States, 10452',
#    'points': 362},
#   {'id': 23222,
#    'start_date': '2024-07-22 08:40:01',
#    'avg_speed': 41,
#    'end_date': '2024-07-22 08:57:31',
#    'length': 12.06,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.05,
#    'type': 'regular',
#    'end_address': '844, Jersey Street, Harrison, New Jersey, United States, 07029',
#    'start_address': 'Penhorn Avenue, Secaucus, New Jersey, United States, 07096',
#    'points': 192},
#   {'id': 23223,
#    'start_date': '2024-07-22 09:06:40',
#    'avg_speed': 40,
#    'end_date': '2024-07-22 09:21:45',
#    'length': 9.97,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.69,
#    'type': 'regular',
#    'end_address': '54, Bruen Avenue, Irvington, New Jersey, United States, 07111',
#    'start_address': '844, Jersey Street, Harrison, New Jersey, United States, 07029',
#    'points': 159},
#   {'id': 23224,
#    'start_date': '2024-07-22 09:30:54',
#    'avg_speed': 43,
#    'end_date': '2024-07-22 09:50:30',
#    'length': 14.05,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.39,
#    'type': 'regular',
#    'end_address': 'Elizabeth, New Jersey, United States, 07002',
#    'start_address': '54, Bruen Avenue, Irvington, New Jersey, United States, 07111',
#    'points': 210},
#   {'id': 23225,
#    'start_date': '2024-07-22 09:59:39',
#    'avg_speed': 45,
#    'end_date': '2024-07-22 10:31:46',
#    'length': 24.16,
#    'max_speed': 59,
#    'norm_fuel_consumed': 4.11,
#    'type': 'regular',
#    'end_address': 'Disposal Road, North Arlington, New Jersey, United States, 07031',
#    'start_address': 'Elizabeth, New Jersey, United States, 07002',
#    'points': 350},
#   {'id': 23226,
#    'start_date': '2024-07-22 10:40:59',
#    'avg_speed': 44,
#    'end_date': '2024-07-22 11:10:13',
#    'length': 21.67,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.68,
#    'type': 'regular',
#    'end_address': 'Vincent R. Casciano Memorial Bridge, NJ 440, Bayonne, New Jersey, United States, 07305',
#    'start_address': 'Disposal Road, North Arlington, New Jersey, United States, 07031',
#    'points': 315},
#   {'id': 23227,
#    'start_date': '2024-07-22 11:19:21',
#    'avg_speed': 46,
#    'end_date': '2024-07-22 12:10:07',
#    'length': 38.98,
#    'max_speed': 59,
#    'norm_fuel_consumed': 6.63,
#    'type': 'regular',
#    'end_address': '3758, Bayview Avenue, New York, United States, 11224',
#    'start_address': 'Vincent R. Casciano Memorial Bridge, NJ 440, Bayonne, New Jersey, United States, 07305',
#    'points': 549},
#   {'id': 23228,
#    'start_date': '2024-07-22 12:19:16',
#    'avg_speed': 45,
#    'end_date': '2024-07-22 12:51:32',
#    'length': 24.31,
#    'max_speed': 59,
#    'norm_fuel_consumed': 4.13,
#    'type': 'regular',
#    'end_address': '473, Herkimer Street, New York, United States, 11213',
#    'start_address': '3758, Bayview Avenue, New York, United States, 11224',
#    'points': 348},
#   {'id': 23229,
#    'start_date': '2024-07-22 13:00:41',
#    'avg_speed': 45,
#    'end_date': '2024-07-22 13:23:32',
#    'length': 16.97,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.88,
#    'type': 'regular',
#    'end_address': 'Shad Creek Road, New York, United States, 11693',
#    'start_address': '473, Herkimer Street, New York, United States, 11213',
#    'points': 250},
#   {'id': 23230,
#    'start_date': '2024-07-22 13:32:36',
#    'avg_speed': 45,
#    'end_date': '2024-07-22 14:01:33',
#    'length': 21.65,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.68,
#    'type': 'regular',
#    'end_address': '8779, 21st Avenue, New York, United States, 11214',
#    'start_address': 'Shad Creek Road, New York, United States, 11693',
#    'points': 318},
#   {'id': 23231,
#    'start_date': '2024-07-22 14:10:39',
#    'avg_speed': 42,
#    'end_date': '2024-07-22 14:20:56',
#    'length': 7.15,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.22,
#    'type': 'regular',
#    'end_address': '2583, Haring Street, New York, United States, 11235',
#    'start_address': '8779, 21st Avenue, New York, United States, 11214',
#    'points': 118},
#   {'id': 23232,
#    'start_date': '2024-07-22 14:30:05',
#    'avg_speed': 45,
#    'end_date': '2024-07-22 14:56:29',
#    'length': 19.92,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.39,
#    'type': 'regular',
#    'end_address': '285, Lightner Avenue, New York, United States, 10314',
#    'start_address': '2583, Haring Street, New York, United States, 11235',
#    'points': 290},
#   {'id': 23233,
#    'start_date': '2024-07-22 15:05:33',
#    'avg_speed': 46,
#    'end_date': '2024-07-22 15:36:10',
#    'length': 23.26,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.95,
#    'type': 'regular',
#    'end_address': 'Newport Parkway, Jersey City, New Jersey, United States, 07310',
#    'start_address': '285, Lightner Avenue, New York, United States, 10314',
#    'points': 344},
#   {'id': 23234,
#    'start_date': '2024-07-22 15:45:16',
#    'avg_speed': 42,
#    'end_date': '2024-07-22 15:58:35',
#    'length': 9.36,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.59,
#    'type': 'regular',
#    'end_address': '284, Neptune Avenue, Jersey City, New Jersey, United States, 07305',
#    'start_address': 'Newport Parkway, Jersey City, New Jersey, United States, 07310',
#    'points': 149},
#   {'id': 23235,
#    'start_date': '2024-07-22 16:07:39',
#    'avg_speed': 43,
#    'end_date': '2024-07-22 16:32:41',
#    'length': 17.9,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.04,
#    'type': 'regular',
#    'end_address': '95, Federal Plaza, Bloomfield, New Jersey, United States, 07003',
#    'start_address': '284, Neptune Avenue, Jersey City, New Jersey, United States, 07305',
#    'points': 273},
#   {'id': 23236,
#    'start_date': '2024-07-22 16:41:50',
#    'avg_speed': 44,
#    'end_date': '2024-07-22 17:08:44',
#    'length': 19.61,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.33,
#    'type': 'regular',
#    'end_address': 'W.B. Mason, Secaucus Road, Secaucus, New Jersey, United States, 07094',
#    'start_address': '95, Federal Plaza, Bloomfield, New Jersey, United States, 07003',
#    'points': 290},
#   {'id': 23237,
#    'start_date': '2024-07-22 17:17:53',
#    'avg_speed': 44,
#    'end_date': '2024-07-22 17:40:16',
#    'length': 16.54,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.81,
#    'type': 'regular',
#    'end_address': 'FDR Drive, New York, United States, 10009',
#    'start_address': 'W.B. Mason, Secaucus Road, Secaucus, New Jersey, United States, 07094',
#    'points': 254},
#   {'id': 23238,
#    'start_date': '2024-07-22 17:49:24',
#    'avg_speed': 42,
#    'end_date': '2024-07-22 18:14:26',
#    'length': 17.64,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.0,
#    'type': 'regular',
#    'end_address': '321, East 83rd Street, Brooklyn Community District 17, New York, United States, 11236',
#    'start_address': 'FDR Drive, New York, United States, 10009',
#    'points': 270},
#   {'id': 23239,
#    'start_date': '2024-07-22 18:23:40',
#    'avg_speed': 43,
#    'end_date': '2024-07-22 18:43:06',
#    'length': 14.06,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.39,
#    'type': 'regular',
#    'end_address': '18, Ocean Avenue, New York, United States, 11697',
#    'start_address': '321, East 83rd Street, Brooklyn Community District 17, New York, United States, 11236',
#    'points': 210},
#   {'id': 23240,
#    'start_date': '2024-07-22 18:52:15',
#    'avg_speed': 47,
#    'end_date': '2024-07-22 19:24:54',
#    'length': 25.39,
#    'max_speed': 59,
#    'norm_fuel_consumed': 4.32,
#    'type': 'regular',
#    'end_address': 'Terminal 1, JFK Access Road, New York, United States, 11430',
#    'start_address': '18, Ocean Avenue, New York, United States, 11697',
#    'points': 360},
#   {'id': 23241,
#    'start_date': '2024-07-22 19:34:03',
#    'avg_speed': 42,
#    'end_date': '2024-07-22 20:02:41',
#    'length': 20.15,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.43,
#    'type': 'regular',
#    'end_address': 'Laurel Hill Boulevard, New York, United States, 11377',
#    'start_address': 'Terminal 1, JFK Access Road, New York, United States, 11430',
#    'points': 312},
#   {'id': 23242,
#    'start_date': '2024-07-22 20:11:47',
#    'avg_speed': 47,
#    'end_date': '2024-07-22 20:43:11',
#    'length': 24.36,
#    'max_speed': 59,
#    'norm_fuel_consumed': 4.14,
#    'type': 'regular',
#    'end_address': '102-14, 165th Avenue, New York, United States, 11414',
#    'start_address': 'Laurel Hill Boulevard, New York, United States, 11377',
#    'points': 339},
#   {'id': 23243,
#    'start_date': '2024-07-22 20:52:20',
#    'avg_speed': 43,
#    'end_date': '2024-07-22 21:16:07',
#    'length': 17.22,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.93,
#    'type': 'regular',
#    'end_address': 'The Woodmere Club, Meadow Drive, Woodmere, Town of Hempstead, New York, United States, 11598',
#    'start_address': '102-14, 165th Avenue, New York, United States, 11414',
#    'points': 256},
#   {'id': 23244,
#    'start_date': '2024-07-22 21:25:16',
#    'avg_speed': 43,
#    'end_date': '2024-07-22 21:42:51',
#    'length': 12.57,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.14,
#    'type': 'regular',
#    'end_address': '142-62, Bascom Avenue, New York, United States, 11436',
#    'start_address': 'The Woodmere Club, Meadow Drive, Woodmere, Town of Hempstead, New York, United States, 11598',
#    'points': 188},
#   {'id': 23245,
#    'start_date': '2024-07-22 21:52:00',
#    'avg_speed': 44,
#    'end_date': '2024-07-22 22:09:35',
#    'length': 12.94,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.2,
#    'type': 'regular',
#    'end_address': '97-16, 35th Avenue, New York, United States, 11368',
#    'start_address': '142-62, Bascom Avenue, New York, United States, 11436',
#    'points': 190},
#   {'id': 23246,
#    'start_date': '2024-07-22 22:18:44',
#    'avg_speed': 42,
#    'end_date': '2024-07-22 22:29:39',
#    'length': 7.7,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.31,
#    'type': 'regular',
#    'end_address': '47-38, Vernon Boulevard, New York, United States, 11101',
#    'start_address': '97-16, 35th Avenue, New York, United States, 11368',
#    'points': 125},
#   {'id': 23247,
#    'start_date': '2024-07-22 22:38:46',
#    'avg_speed': 42,
#    'end_date': '2024-07-22 23:08:40',
#    'length': 20.91,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.55,
#    'type': 'regular',
#    'end_address': '95, Jacobus Avenue, Kearny Point, Kearny, New Jersey, United States, 07032',
#    'start_address': '47-38, Vernon Boulevard, New York, United States, 11101',
#    'points': 322},
#   {'id': 23248,
#    'start_date': '2024-07-22 23:22:31',
#    'avg_speed': 40,
#    'end_date': '2024-07-22 23:51:10',
#    'length': 19.29,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.28,
#    'type': 'regular',
#    'end_address': 'Pier 8, Congress Street, Brooklyn Port Authority Marine Terminal, New York, United States, 11201',
#    'start_address': '95, Jacobus Avenue, Kearny Point, Kearny, New Jersey, United States, 07032',
#    'points': 309},
#   {'id': 23249,
#    'start_date': '2024-07-23 00:00:18',
#    'avg_speed': 44,
#    'end_date': '2024-07-23 00:11:43',
#    'length': 8.33,
#    'max_speed': 59,
#    'norm_fuel_consumed': 1.42,
#    'type': 'regular',
#    'end_address': '23, East 20th Street, New York, United States, 10010',
#    'start_address': 'Pier 8, Congress Street, Brooklyn Port Authority Marine Terminal, New York, United States, 11201',
#    'points': 127},
#   {'id': 23250,
#    'start_date': '2024-07-23 00:20:46',
#    'avg_speed': 41,
#    'end_date': '2024-07-23 00:47:28',
#    'length': 18.31,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.11,
#    'type': 'regular',
#    'end_address': '1313, 53rd Street, New York, United States, 11219',
#    'start_address': '23, East 20th Street, New York, United States, 10010',
#    'points': 293},
#   {'id': 23251,
#    'start_date': '2024-07-23 00:56:39',
#    'avg_speed': 44,
#    'end_date': '2024-07-23 01:21:25',
#    'length': 18.25,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.1,
#    'type': 'regular',
#    'end_address': 'Marine Parkway Bridge, Marine Parkway–Gil Hodges Memorial Bridge, New York, United States, 11697',
#    'start_address': '1313, 53rd Street, New York, United States, 11219',
#    'points': 275},
#   {'id': 23252,
#    'start_date': '2024-07-23 01:30:34',
#    'avg_speed': 46,
#    'end_date': '2024-07-23 01:52:41',
#    'length': 17.03,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.9,
#    'type': 'regular',
#    'end_address': 'Cypress Avenue, New York, United States, 11232',
#    'start_address': 'Marine Parkway Bridge, Marine Parkway–Gil Hodges Memorial Bridge, New York, United States, 11697',
#    'points': 239},
#   {'id': 23253,
#    'start_date': '2024-07-23 02:01:50',
#    'avg_speed': 44,
#    'end_date': '2024-07-23 02:25:17',
#    'length': 17.19,
#    'max_speed': 59,
#    'norm_fuel_consumed': 2.92,
#    'type': 'regular',
#    'end_address': 'NYPD Air Operations Heliport (Floyd Bennett Field), Aviation Road, New York, United States, 11234',
#    'start_address': 'Cypress Avenue, New York, United States, 11232',
#    'points': 250},
#   {'id': 23254,
#    'start_date': '2024-07-23 02:34:25',
#    'avg_speed': 45,
#    'end_date': '2024-07-23 02:58:03',
#    'length': 17.92,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.05,
#    'type': 'regular',
#    'end_address': 'Nassau Expressway, New York, United States, 11420',
#    'start_address': 'NYPD Air Operations Heliport (Floyd Bennett Field), Aviation Road, New York, United States, 11234',
#    'points': 257},
#   {'id': 23255,
#    'start_date': '2024-07-23 03:07:12',
#    'avg_speed': 46,
#    'end_date': '2024-07-23 03:35:55',
#    'length': 22.09,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.76,
#    'type': 'regular',
#    'end_address': 'Red Trail, New York, United States, 11229',
#    'start_address': 'Nassau Expressway, New York, United States, 11420',
#    'points': 317},
#   {'id': 23256,
#    'start_date': '2024-07-23 03:45:01',
#    'avg_speed': 47,
#    'end_date': '2024-07-23 04:10:01',
#    'length': 19.58,
#    'max_speed': 59,
#    'norm_fuel_consumed': 3.33,
#    'type': 'regular',
#    'end_address': 'Nassau Expressway, New York, United States, 11420',
#    'start_address': 'Red Trail, New York, United States, 11229',
#    'points': 274}],
#  'limit_exceeded': False,
#  'success': True}

# %%
pd.json_normalize(response.json()['list'])
# Out:
#         id           start_date  avg_speed             end_date  length  \
# 0    22469  2024-07-01 00:07:27         45  2024-07-01 00:28:47   16.14
# 1    22470  2024-07-01 00:37:53         45  2024-07-01 01:04:18   19.70
# 2    22471  2024-07-01 01:13:24         43  2024-07-01 01:26:13    9.15
# 3    22472  2024-07-01 01:35:20         45  2024-07-01 01:49:24   10.44
# 4    22473  2024-07-01 01:58:30         46  2024-07-01 02:12:35   10.69
# ..     ...                  ...        ...                  ...     ...
# 783  23252  2024-07-23 01:30:34         46  2024-07-23 01:52:41   17.03
# 784  23253  2024-07-23 02:01:50         44  2024-07-23 02:25:17   17.19
# 785  23254  2024-07-23 02:34:25         45  2024-07-23 02:58:03   17.92
# 786  23255  2024-07-23 03:07:12         46  2024-07-23 03:35:55   22.09
# 787  23256  2024-07-23 03:45:01         47  2024-07-23 04:10:01   19.58
#
#      max_speed  norm_fuel_consumed     type  \
# 0           59                2.74  regular
# 1           59                3.35  regular
# 2           59                1.56  regular
# 3           59                1.77  regular
# 4           59                1.82  regular
# ..         ...                 ...      ...
# 783         59                2.90  regular
# 784         59                2.92  regular
# 785         59                3.05  regular
# 786         59                3.76  regular
# 787         59                3.33  regular
#
#                                            end_address  \
# 0    34, Orchard Place, Hawthorne, New Jersey, Unit...
# 1    88, Chadwick Court, Park Ridge, Bergen County,...
# 2    740, Pascack Road, Paramus, New Jersey, United...
# 3    158, Baker Avenue, Bergenfield, New Jersey, Un...
# 4    43, Van Orden Road, Harrington Park, Bergen Co...
# ..                                                 ...
# 783     Cypress Avenue, New York, United States, 11232
# 784  NYPD Air Operations Heliport (Floyd Bennett Fi...
# 785  Nassau Expressway, New York, United States, 11420
# 786          Red Trail, New York, United States, 11229
# 787  Nassau Expressway, New York, United States, 11420
#
#                                          start_address  points
# 0    Preakness HIlls Country Club, 1050, Ratzer Roa...     237
# 1    34, Orchard Place, Hawthorne, New Jersey, Unit...     279
# 2    88, Chadwick Court, Park Ridge, Bergen County,...     138
# 3    740, Pascack Road, Paramus, New Jersey, United...     157
# 4    158, Baker Avenue, Bergenfield, New Jersey, Un...     159
# ..                                                 ...     ...
# 783  Marine Parkway Bridge, Marine Parkway–Gil Hodg...     239
# 784     Cypress Avenue, New York, United States, 11232     250
# 785  NYPD Air Operations Heliport (Floyd Bennett Fi...     257
# 786  Nassau Expressway, New York, United States, 11420     317
# 787          Red Trail, New York, United States, 11229     274
#
# [788 rows x 11 columns]

# %%
df = pd.json_normalize(fuel)
df = df.explode('inputs')
if pd.isna(df.loc[0, 'inputs']) == False:
    df = pd.concat([df.drop(['inputs'], axis=1), df['inputs'].apply(pd.Series)], axis=1)

# %%
df = df.astype({"id": int}).merge(pd.json_normalize(response_json['list'])[['id', 'label']], on='id')
